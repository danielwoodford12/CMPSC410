# %% [markdown]
# # DS/CMPSC 410 MiniProject Deliverable #1
#
# # Fall 2024
# ## Instructor: Prof. John Yen
# ## TAs: Jin, Peng and Al Lawati, Ali Hussain Mohsin
#
# ## Learning Objectives
# - Be able to identify frequent 1 ports, 2 port sets and 3 port sets (based on a threshold) that are scanned by scanners in the Darknet dataset.
# - Be able to adapt the Aprior algorithm by incorporating suitable threshold and pruning strategies.
# - Be able to improve the performance of frequent port set mining by suitable reuse of RDD, together with appropriate persist and unpersist on the reused RDD.
# - After successful execution in the local mode, modify the code for cluster mode, and final frequent 1-ports, 2-port sets, and 3-port sets using the big Darknet dataset (`Day_2020_profile.csv`).
#
# ### Data
# - The small Darknet dataset 'sampled_profile.csv' and the large Darknet dataset `Day_2020_profile.csv` are available for download from Canvas, then upload to Roar under your MiniProj1 directory in work directory.
#
# ### Items to submit:
# - Completed Jupyter Notebook (using small Darknet dataset `sampled_profile.csv`) in HTML format.
# - .py file for mining frequent 1 ports, 2 port sets. and 3 port sets in cluster mode using the big Darknet dataset `Day_2020_profile.csv`.
# - one csv file of frequent 1-ports generated in the CLUSTEr mode.
# - one csv file of frequent 2-port sets generated in the CLUSTER mode.
# - one csv file of frequent 3-port sets generated in the CLUSTER mode.
# - a screen shot (using ``ls -l`` terminal command) of the MiniProj1 directory, showing all files and directories2
#
# ### Due: midnight, November 12, 2024

# %%
import pyspark
import csv
import pandas as pd

# %%
from pyspark import SparkContext
from pyspark.sql import SparkSession
from pyspark.sql.types import StructField, StructType, IntegerType, BooleanType, StringType, DecimalType
from pyspark.sql.functions import col, column
from pyspark.sql.functions import expr
from pyspark.sql.functions import split
from pyspark.sql import Row
from pyspark.ml import Pipeline
from pyspark.ml.feature import OneHotEncoder, StringIndexer, VectorAssembler, IndexToString
from pyspark.ml.clustering import KMeans

# %%
ss = SparkSession.builder.master("local").appName("Mini Project #1 Freqent Port Sets Mining").getOrCreate()
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/storage/icds/RISE/sw8/anaconda3-2021.11/conda_envs/pyspark/lib/python3.10/site-packages/pyspark/jars/spark-unsafe_2.12-3.2.1.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/10/30 23:21:18 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
ss.sparkContext.setLogLevel("WARN")

# %%
# ss.sparkContext.setCheckpointDir("~/scratch")

# %%
scanner_schema = StructType([StructField("_c0", IntegerType(), False), \
                             StructField("id", IntegerType(), False ), \
                             StructField("numports", IntegerType(), False), \
                             StructField("lifetime", DecimalType(), False ), \
                             StructField("Bytes", IntegerType(), False ), \
                             StructField("Packets", IntegerType(), False), \
                             StructField("average_packetsize", IntegerType(), False), \
                             StructField("MinUniqueDests", IntegerType(), False),\
                             StructField("MaxUniqueDests", IntegerType(), False), \
                             StructField("MinUniqueDest24s", IntegerType(), False), \
                             StructField("MaxUniqueDest24s", IntegerType(), False), \
                             StructField("average_lifetime", DecimalType(), False), \
                             StructField("mirai", BooleanType(), True), \
                             StructField("zmap", BooleanType(), True),
                             StructField("masscan", BooleanType(), True),
                             StructField("country", StringType(), False), \
                             StructField("traffic_types_scanned_str", StringType(), False), \
                             StructField("ports_scanned_str", StringType(), False), \
                             StructField("host_tags_per_censys", StringType(), False), \
                             StructField("host_services_per_censys", StringType(), False) \
                           ])

# %%
# In the cluster mode, change this line to
# Scanners_df = ss.read.csv("/storage/home/???/work/MiniProj1/Day_2020_profile.csv", schema = scanner_schema, header= True, inferSchema=False )
Scanners_df = ss.read.csv("sampled_profile.csv", schema = scanner_schema, \
                          header=True, inferSchema=False)

# %%
Scanners_df.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- id: integer (nullable = true)
#  |-- numports: integer (nullable = true)
#  |-- lifetime: decimal(10,0) (nullable = true)
#  |-- Bytes: integer (nullable = true)
#  |-- Packets: integer (nullable = true)
#  |-- average_packetsize: integer (nullable = true)
#  |-- MinUniqueDests: integer (nullable = true)
#  |-- MaxUniqueDests: integer (nullable = true)
#  |-- MinUniqueDest24s: integer (nullable = true)
#  |-- MaxUniqueDest24s: integer (nullable = true)
#  |-- average_lifetime: decimal(10,0) (nullable = true)
#  |-- mirai: boolean (nullable = true)
#  |-- zmap: boolean (nullable = true)
#  |-- masscan: boolean (nullable = true)
#  |-- country: string (nullable = true)
#  |-- traffic_types_scanned_str: string (nullable = true)
#  |-- ports_scanned_str: string (nullable = true)
#  |-- host_tags_per_censys: string (nullable = true)
#  |-- host_services_per_censys: string (nullable = true)

# %% [markdown]
# ## Read scanners data, parse the ports_scanned_str into an array

# %%
Scanners_df2=Scanners_df.withColumn("Ports_Array", split(col("ports_scanned_str"), "-") )

# %%
Ports_Scanned_RDD = Scanners_df2.select("Ports_Array").rdd

# %%
scanner_port_list_RDD = Ports_Scanned_RDD.map(lambda x: x["Ports_Array"])

# %% [markdown]
# ## Compute the total number of scanners scanning each port

# %%
port_list_RDD = scanner_port_list_RDD.flatMap(lambda x: x)

# %%
port_1_RDD = port_list_RDD.map(lambda x: (x, 1) )
port_1_RDD.take(5)
# Out:
# [('13716', 1), ('17128', 1), ('17136', 1), ('35134', 1), ('17140', 1)]

# %%
port_count_RDD = port_1_RDD.reduceByKey(lambda x,y: x + y, 8)
port_count_RDD.take(5)
# Out:
# [('8443', 4012),
#  ('34230', 1921),
#  ('5564', 18),
#  ('33966', 1919),
#  ('33972', 3130)]

# %%
sorted_count_port_RDD = port_count_RDD.map(lambda x: (x[1], x[0])).sortByKey(ascending = False)

# %%
sorted_count_port_RDD.take(20)
# Out:
# [(32014, '17132'),
#  (31865, '17140'),
#  (31850, '17128'),
#  (31805, '17138'),
#  (31630, '17130'),
#  (31617, '17136'),
#  (29199, '23'),
#  (25466, '445'),
#  (25216, '54594'),
#  (21700, '17142'),
#  (21560, '17134'),
#  (15010, '80'),
#  (13698, '8080'),
#  (8778, '0'),
#  (6265, '2323'),
#  (5552, '5555'),
#  (4930, '81'),
#  (4103, '1023'),
#  (4058, '52869'),
#  (4012, '8443')]

# %%
sorted_port_count = "sorted_port_count_local.txt"
sorted_count_port_RDD.saveAsTextFile(sorted_port_count)

# %% [markdown]
# ## Filter for ports whose count of scanners (scanning the port) exceeds the thresdhold

# %%
threshold = 500
freq_count_port_RDD= sorted_count_port_RDD.filter(lambda x: x[0] > threshold)
total_freq_port_count = freq_count_port_RDD.count()

# %%
total_freq_port_count
# Out:
# 48

# %%
DF1port = ss.createDataFrame(freq_count_port_RDD)
output_path_1_port = "freq_1_port_count_local.csv"
DF1port.write.option("header", True).csv(output_path_1_port)

# %%
Top_Ports = freq_count_port_RDD.map(lambda x: x[1]).collect()

# %%
print(Top_Ports)
# Out:
# ['17132', '17140', '17128', '17138', '17130', '17136', '23', '445', '54594', '17142', '17134', '80', '8080', '0', '2323', '5555', '81', '1023', '52869', '8443', '49152', '7574', '37215', '34218', '34220', '33968', '34224', '34228', '33962', '33960', '33964', '34216', '34226', '33970', '33972', '50401', '34222', '34230', '33966', '33974', '3389', '1433', '22', '5353', '21', '8291', '8728', '443']

# %%
Top_1_Port_count = len(Top_Ports)

# %%
print(Top_1_Port_count)
# Out:
# 48

# %% [markdown]
# # Finding Frequent Port Sets Being Scanned

# %% [markdown]
# ## Pruning Strategy

# %%
scanner_port_list_RDD.take(5)
# Out:
# [['13716'], ['17128', '17136'], ['35134'], ['17140'], ['54594']]

# %%
scanner_port_list_RDD.count()
# Out:
# 227062

# %%
MPscanner_port_list_RDD = scanner_port_list_RDD.filter(lambda x: len(x) >= 2 )

# %%
MPscanner_port_list_RDD.take(5)
# Out:
# [['17128', '17136'],
#  ['17128', '17130', '17132', '17134', '17136', '17138', '17140'],
#  ['23',
#   '80',
#   '81',
#   '1023',
#   '2323',
#   '5555',
#   '7574',
#   '8080',
#   '8443',
#   '37215',
#   '49152',
#   '52869'],
#  ['17128', '17132', '17136', '17140', '17142', '34230'],
#  ['137', '17130']]

# %%
multi_port_scanner_count = MPscanner_port_list_RDD.count()
print(multi_port_scanner_count)
# Out:
# [Stage 31:>                                                         (0 + 1) / 1]
# 73663

# %%
scanner_count= scanner_port_list_RDD.count()
print(scanner_count)
# Out:
# [Stage 32:>                                                         (0 + 1) / 1]
# 227062

# %% [markdown]
# ## Filter for scanners who scan one or more specific ports, then count the number of scanners that satisfy that criteria.

# %%
count_80_23 = MPscanner_port_list_RDD.filter(lambda x: ('80' in x) and ('23' in x)).count()

# %%
print(count_80_23)
# Out:
# 10427

# %%
count2_80_23 = MPscanner_port_list_RDD.filter(lambda x: ('80' in x)).filter(lambda x: ('23' in x)).count()

# %%
print(count2_80_23)
# Out:
# 10427

# %% [markdown]
# ## Display the content of a few RDD to double check that we do not see any 1-port scanners in the RDD.

# %%
MPscanner_port_list_RDD.take(5)
# Out:
# [['17128', '17136'],
#  ['17128', '17130', '17132', '17134', '17136', '17138', '17140'],
#  ['23',
#   '80',
#   '81',
#   '1023',
#   '2323',
#   '5555',
#   '7574',
#   '8080',
#   '8443',
#   '37215',
#   '49152',
#   '52869'],
#  ['17128', '17132', '17136', '17140', '17142', '34230'],
#  ['137', '17130']]

# %% [markdown]
# # Frequent 1 Port Sets
# Earlier, we have saved the list of frequent 1 port set (the set of ports who have been scanned by more than x scanners, where x is the threshold) in the variable Top_Ports

# %%
print(Top_Ports)
# Out:
# ['17132', '17140', '17128', '17138', '17130', '17136', '23', '445', '54594', '17142', '17134', '80', '8080', '0', '2323', '5555', '81', '1023', '52869', '8443', '49152', '7574', '37215', '34218', '34220', '33968', '34224', '34228', '33962', '33960', '33964', '34216', '34226', '33970', '33972', '50401', '34222', '34230', '33966', '33974', '3389', '1433', '22', '5353', '21', '8291', '8728', '443']

# %% [markdown]
# # Finding Frequent 2-Port Sets

# %%
Top_1_Port_count = len(Top_Ports)

# %%
print(Top_1_Port_count)
# Out:
# 48

# %%
# Initialize a Pandas DataFrame to store frequent port sets and their counts 
Two_Port_Sets_df = pd.DataFrame( columns = ['Port Sets', 'count'])
# Initialize the index to Two_Port_Sets_df
index2 = 0
threshold = 500
MPscanner_port_list_RDD.persist()
for i in range(0, Top_1_Port_count):
    filtered_scanners_TP_i = MPscanner_port_list_RDD.filter(lambda x: Top_Ports[i] in x)
    filtered_scanners_TP_i.persist()  
    # We do not need to filter for threshold for 1-port sets because all ports in Top_Ports have a
    # frequency higher than the threshold.
    for j in range(i+1, Top_1_Port_count):
        filtered_scanners_TP_i_j = filtered_scanners_TP_i.filter(lambda x: Top_Ports[j] in x)
        port_i_j_count = filtered_scanners_TP_i_j.count()
        if port_i_j_count > threshold:
            Two_Port_Sets_df.loc[index2] = [ Top_Ports[i]+"-"+Top_Ports[j], port_i_j_count] 
            index2 = index2 + 1
            # The print statement is for running in the local mode.  It can be commented out for running in the cluster mode.
            print("Two Ports:", Top_Ports[i], " , ", Top_Ports[j], ", Count: ", port_i_j_count)
    filtered_scanners_TP_i.unpersist()
# Out:
# Two Ports: 17132  ,  17140 , Count:  16317
# Two Ports: 17132  ,  17128 , Count:  16279
# Two Ports: 17132  ,  17138 , Count:  16299
# Two Ports: 17132  ,  17130 , Count:  16336
# Two Ports: 17132  ,  17136 , Count:  16148
# Two Ports: 17132  ,  17142 , Count:  12722
# Two Ports: 17132  ,  17134 , Count:  12761
# Two Ports: 17132  ,  34218 , Count:  2658
# Two Ports: 17132  ,  34220 , Count:  2666
# Two Ports: 17132  ,  33968 , Count:  2608
# Two Ports: 17132  ,  34224 , Count:  2619
# Two Ports: 17132  ,  34228 , Count:  2624
# Two Ports: 17132  ,  33962 , Count:  2591
# Two Ports: 17132  ,  33960 , Count:  2628
# Two Ports: 17132  ,  33964 , Count:  2567
# Two Ports: 17132  ,  34216 , Count:  2552
# Two Ports: 17132  ,  34226 , Count:  2555
# Two Ports: 17132  ,  33970 , Count:  2540
# Two Ports: 17132  ,  33972 , Count:  2564
# Two Ports: 17132  ,  34222 , Count:  1630
# Two Ports: 17132  ,  34230 , Count:  1599
# Two Ports: 17132  ,  33966 , Count:  1594
# Two Ports: 17132  ,  33974 , Count:  1484
# Two Ports: 17140  ,  17128 , Count:  16161
# Two Ports: 17140  ,  17138 , Count:  16145
# Two Ports: 17140  ,  17130 , Count:  16312
# Two Ports: 17140  ,  17136 , Count:  16078
# Two Ports: 17140  ,  17142 , Count:  12753
# Two Ports: 17140  ,  17134 , Count:  12634
# Two Ports: 17140  ,  34218 , Count:  2641
# Two Ports: 17140  ,  34220 , Count:  2631
# Two Ports: 17140  ,  33968 , Count:  2629
# Two Ports: 17140  ,  34224 , Count:  2640
# Two Ports: 17140  ,  34228 , Count:  2633
# Two Ports: 17140  ,  33962 , Count:  2611
# Two Ports: 17140  ,  33960 , Count:  2580
# Two Ports: 17140  ,  33964 , Count:  2544
# Two Ports: 17140  ,  34216 , Count:  2540
# Two Ports: 17140  ,  34226 , Count:  2553
# Two Ports: 17140  ,  33970 , Count:  2526
# Two Ports: 17140  ,  33972 , Count:  2561
# Two Ports: 17140  ,  34222 , Count:  1636
# Two Ports: 17140  ,  34230 , Count:  1592
# Two Ports: 17140  ,  33966 , Count:  1591
# Two Ports: 17140  ,  33974 , Count:  1504
# Two Ports: 17128  ,  17138 , Count:  16027
# Two Ports: 17128  ,  17130 , Count:  16217
# Two Ports: 17128  ,  17136 , Count:  16151
# Two Ports: 17128  ,  17142 , Count:  12712
# Two Ports: 17128  ,  17134 , Count:  12763
# Two Ports: 17128  ,  34218 , Count:  2690
# Two Ports: 17128  ,  34220 , Count:  2617
# Two Ports: 17128  ,  33968 , Count:  2617
# Two Ports: 17128  ,  34224 , Count:  2620
# Two Ports: 17128  ,  34228 , Count:  2632
# Two Ports: 17128  ,  33962 , Count:  2638
# Two Ports: 17128  ,  33960 , Count:  2618
# Two Ports: 17128  ,  33964 , Count:  2550
# Two Ports: 17128  ,  34216 , Count:  2579
# Two Ports: 17128  ,  34226 , Count:  2541
# Two Ports: 17128  ,  33970 , Count:  2520
# Two Ports: 17128  ,  33972 , Count:  2572
# Two Ports: 17128  ,  34222 , Count:  1635
# Two Ports: 17128  ,  34230 , Count:  1581
# Two Ports: 17128  ,  33966 , Count:  1599
# Two Ports: 17128  ,  33974 , Count:  1481
# Two Ports: 17138  ,  17130 , Count:  16204
# Two Ports: 17138  ,  17136 , Count:  16001
# Two Ports: 17138  ,  17142 , Count:  12620
# Two Ports: 17138  ,  17134 , Count:  12741
# Two Ports: 17138  ,  34218 , Count:  2663
# Two Ports: 17138  ,  34220 , Count:  2593
# Two Ports: 17138  ,  33968 , Count:  2604
# Two Ports: 17138  ,  34224 , Count:  2622
# Two Ports: 17138  ,  34228 , Count:  2590
# Two Ports: 17138  ,  33962 , Count:  2609
# Two Ports: 17138  ,  33960 , Count:  2596
# Two Ports: 17138  ,  33964 , Count:  2551
# Two Ports: 17138  ,  34216 , Count:  2558
# Two Ports: 17138  ,  34226 , Count:  2577
# Two Ports: 17138  ,  33970 , Count:  2545
# Two Ports: 17138  ,  33972 , Count:  2555
# Two Ports: 17138  ,  34222 , Count:  1624
# Two Ports: 17138  ,  34230 , Count:  1581
# Two Ports: 17138  ,  33966 , Count:  1579
# Two Ports: 17138  ,  33974 , Count:  1485
# Two Ports: 17130  ,  17136 , Count:  16061
# Two Ports: 17130  ,  17142 , Count:  12675
# Two Ports: 17130  ,  17134 , Count:  12777
# Two Ports: 17130  ,  34218 , Count:  2681
# Two Ports: 17130  ,  34220 , Count:  2603
# Two Ports: 17130  ,  33968 , Count:  2624
# Two Ports: 17130  ,  34224 , Count:  2617
# Two Ports: 17130  ,  34228 , Count:  2583
# Two Ports: 17130  ,  33962 , Count:  2629
# Two Ports: 17130  ,  33960 , Count:  2604
# Two Ports: 17130  ,  33964 , Count:  2546
# Two Ports: 17130  ,  34216 , Count:  2539
# Two Ports: 17130  ,  34226 , Count:  2548
# Two Ports: 17130  ,  33970 , Count:  2559
# Two Ports: 17130  ,  33972 , Count:  2539
# Two Ports: 17130  ,  34222 , Count:  1616
# Two Ports: 17130  ,  34230 , Count:  1580
# Two Ports: 17130  ,  33966 , Count:  1591
# Two Ports: 17130  ,  33974 , Count:  1484
# Two Ports: 17136  ,  17142 , Count:  12584
# Two Ports: 17136  ,  17134 , Count:  12711
# Two Ports: 17136  ,  34218 , Count:  2649
# Two Ports: 17136  ,  34220 , Count:  2623
# Two Ports: 17136  ,  33968 , Count:  2606
# Two Ports: 17136  ,  34224 , Count:  2640
# Two Ports: 17136  ,  34228 , Count:  2602
# Two Ports: 17136  ,  33962 , Count:  2609
# Two Ports: 17136  ,  33960 , Count:  2607
# Two Ports: 17136  ,  33964 , Count:  2555
# Two Ports: 17136  ,  34216 , Count:  2569
# Two Ports: 17136  ,  34226 , Count:  2558
# Two Ports: 17136  ,  33970 , Count:  2528
# Two Ports: 17136  ,  33972 , Count:  2545
# Two Ports: 17136  ,  34222 , Count:  1620
# Two Ports: 17136  ,  34230 , Count:  1581
# Two Ports: 17136  ,  33966 , Count:  1589
# Two Ports: 17136  ,  33974 , Count:  1488
# Two Ports: 23  ,  80 , Count:  10427
# Two Ports: 23  ,  8080 , Count:  10447
# Two Ports: 23  ,  2323 , Count:  4340
# Two Ports: 23  ,  5555 , Count:  2650
# Two Ports: 23  ,  81 , Count:  3469
# Two Ports: 23  ,  1023 , Count:  2726
# Two Ports: 23  ,  52869 , Count:  2677
# Two Ports: 23  ,  8443 , Count:  2657
# Two Ports: 23  ,  49152 , Count:  2622
# Two Ports: 23  ,  7574 , Count:  2548
# Two Ports: 23  ,  37215 , Count:  2560
# Two Ports: 54594  ,  50401 , Count:  2344
# Two Ports: 17142  ,  17134 , Count:  10340
# Two Ports: 17142  ,  34218 , Count:  2412
# Two Ports: 17142  ,  34220 , Count:  2372
# Two Ports: 17142  ,  33968 , Count:  2389
# Two Ports: 17142  ,  34224 , Count:  2415
# Two Ports: 17142  ,  34228 , Count:  2379
# Two Ports: 17142  ,  33962 , Count:  2402
# Two Ports: 17142  ,  33960 , Count:  2379
# Two Ports: 17142  ,  33964 , Count:  2311
# Two Ports: 17142  ,  34216 , Count:  2319
# Two Ports: 17142  ,  34226 , Count:  2335
# Two Ports: 17142  ,  33970 , Count:  2330
# Two Ports: 17142  ,  33972 , Count:  2315
# Two Ports: 17142  ,  34222 , Count:  1511
# Two Ports: 17142  ,  34230 , Count:  1475
# Two Ports: 17142  ,  33966 , Count:  1476
# Two Ports: 17142  ,  33974 , Count:  1378
# Two Ports: 17134  ,  34218 , Count:  2441
# Two Ports: 17134  ,  34220 , Count:  2398
# Two Ports: 17134  ,  33968 , Count:  2387
# Two Ports: 17134  ,  34224 , Count:  2405
# Two Ports: 17134  ,  34228 , Count:  2357
# Two Ports: 17134  ,  33962 , Count:  2388
# Two Ports: 17134  ,  33960 , Count:  2366
# Two Ports: 17134  ,  33964 , Count:  2305
# Two Ports: 17134  ,  34216 , Count:  2348
# Two Ports: 17134  ,  34226 , Count:  2366
# Two Ports: 17134  ,  33970 , Count:  2306
# Two Ports: 17134  ,  33972 , Count:  2315
# Two Ports: 17134  ,  34222 , Count:  1519
# Two Ports: 17134  ,  34230 , Count:  1470
# Two Ports: 17134  ,  33966 , Count:  1489
# Two Ports: 17134  ,  33974 , Count:  1385
# Two Ports: 80  ,  8080 , Count:  12601
# Two Ports: 80  ,  2323 , Count:  4451
# Two Ports: 80  ,  5555 , Count:  3887
# Two Ports: 80  ,  81 , Count:  3956
# Two Ports: 80  ,  1023 , Count:  3986
# Two Ports: 80  ,  52869 , Count:  3917
# Two Ports: 80  ,  8443 , Count:  3924
# Two Ports: 80  ,  49152 , Count:  3869
# Two Ports: 80  ,  7574 , Count:  3798
# Two Ports: 80  ,  37215 , Count:  3803
# Two Ports: 8080  ,  2323 , Count:  4461
# Two Ports: 8080  ,  5555 , Count:  3835
# Two Ports: 8080  ,  81 , Count:  3933
# Two Ports: 8080  ,  1023 , Count:  3965
# Two Ports: 8080  ,  52869 , Count:  3900
# Two Ports: 8080  ,  8443 , Count:  3896
# Two Ports: 8080  ,  49152 , Count:  3847
# Two Ports: 8080  ,  7574 , Count:  3769
# Two Ports: 8080  ,  37215 , Count:  3770
# Two Ports: 2323  ,  5555 , Count:  3645
# Two Ports: 2323  ,  81 , Count:  3707
# Two Ports: 2323  ,  1023 , Count:  3950
# Two Ports: 2323  ,  52869 , Count:  3711
# Two Ports: 2323  ,  8443 , Count:  3714
# Two Ports: 2323  ,  49152 , Count:  3680
# Two Ports: 2323  ,  7574 , Count:  3607
# Two Ports: 2323  ,  37215 , Count:  3666
# Two Ports: 5555  ,  81 , Count:  3411
# Two Ports: 5555  ,  1023 , Count:  3425
# Two Ports: 5555  ,  52869 , Count:  3419
# Two Ports: 5555  ,  8443 , Count:  3444
# Two Ports: 5555  ,  49152 , Count:  3405
# Two Ports: 5555  ,  7574 , Count:  3330
# Two Ports: 5555  ,  37215 , Count:  3339
# Two Ports: 81  ,  1023 , Count:  3481
# Two Ports: 81  ,  52869 , Count:  3456
# Two Ports: 81  ,  8443 , Count:  3489
# Two Ports: 81  ,  49152 , Count:  3438
# Two Ports: 81  ,  7574 , Count:  3377
# Two Ports: 81  ,  37215 , Count:  3396
# Two Ports: 1023  ,  52869 , Count:  3477
# Two Ports: 1023  ,  8443 , Count:  3493
# Two Ports: 1023  ,  49152 , Count:  3462
# Two Ports: 1023  ,  7574 , Count:  3396
# Two Ports: 1023  ,  37215 , Count:  3384
# Two Ports: 52869  ,  8443 , Count:  3473
# Two Ports: 52869  ,  49152 , Count:  3452
# Two Ports: 52869  ,  7574 , Count:  3387
# Two Ports: 52869  ,  37215 , Count:  3385
# Two Ports: 8443  ,  49152 , Count:  3452
# Two Ports: 8443  ,  7574 , Count:  3398
# Two Ports: 8443  ,  37215 , Count:  3392
# Two Ports: 49152  ,  7574 , Count:  3375
# Two Ports: 49152  ,  37215 , Count:  3371
# Two Ports: 7574  ,  37215 , Count:  3308
# Two Ports: 34218  ,  34220 , Count:  1021
# Two Ports: 34218  ,  33968 , Count:  1045
# Two Ports: 34218  ,  34224 , Count:  1092
# Two Ports: 34218  ,  34228 , Count:  999
# Two Ports: 34218  ,  33962 , Count:  1038
# Two Ports: 34218  ,  33960 , Count:  1026
# Two Ports: 34218  ,  33964 , Count:  991
# Two Ports: 34218  ,  34216 , Count:  1003
# Two Ports: 34218  ,  34226 , Count:  1031
# Two Ports: 34218  ,  33970 , Count:  1003
# Two Ports: 34218  ,  33972 , Count:  990
# Two Ports: 34218  ,  34222 , Count:  722
# Two Ports: 34218  ,  34230 , Count:  698
# Two Ports: 34218  ,  33966 , Count:  710
# Two Ports: 34218  ,  33974 , Count:  668
# Two Ports: 34220  ,  33968 , Count:  1035
# Two Ports: 34220  ,  34224 , Count:  1049
# Two Ports: 34220  ,  34228 , Count:  1000
# Two Ports: 34220  ,  33962 , Count:  1018
# Two Ports: 34220  ,  33960 , Count:  1002
# Two Ports: 34220  ,  33964 , Count:  1015
# Two Ports: 34220  ,  34216 , Count:  984
# Two Ports: 34220  ,  34226 , Count:  1014
# Two Ports: 34220  ,  33970 , Count:  979
# Two Ports: 34220  ,  33972 , Count:  990
# Two Ports: 34220  ,  34222 , Count:  750
# Two Ports: 34220  ,  34230 , Count:  698
# Two Ports: 34220  ,  33966 , Count:  705
# Two Ports: 34220  ,  33974 , Count:  662
# Two Ports: 33968  ,  34224 , Count:  1051
# Two Ports: 33968  ,  34228 , Count:  1002
# Two Ports: 33968  ,  33962 , Count:  1015
# Two Ports: 33968  ,  33960 , Count:  1037
# Two Ports: 33968  ,  33964 , Count:  1007
# Two Ports: 33968  ,  34216 , Count:  1013
# Two Ports: 33968  ,  34226 , Count:  1026
# Two Ports: 33968  ,  33970 , Count:  1004
# Two Ports: 33968  ,  33972 , Count:  992
# Two Ports: 33968  ,  34222 , Count:  727
# Two Ports: 33968  ,  34230 , Count:  702
# Two Ports: 33968  ,  33966 , Count:  692
# Two Ports: 33968  ,  33974 , Count:  666
# Two Ports: 34224  ,  34228 , Count:  1009
# Two Ports: 34224  ,  33962 , Count:  1029
# Two Ports: 34224  ,  33960 , Count:  1031
# Two Ports: 34224  ,  33964 , Count:  1005
# Two Ports: 34224  ,  34216 , Count:  1023
# Two Ports: 34224  ,  34226 , Count:  1027
# Two Ports: 34224  ,  33970 , Count:  1012
# Two Ports: 34224  ,  33972 , Count:  1018
# Two Ports: 34224  ,  34222 , Count:  733
# Two Ports: 34224  ,  34230 , Count:  696
# Two Ports: 34224  ,  33966 , Count:  719
# Two Ports: 34224  ,  33974 , Count:  663
# Two Ports: 34228  ,  33962 , Count:  1023
# Two Ports: 34228  ,  33960 , Count:  983
# Two Ports: 34228  ,  33964 , Count:  981
# Two Ports: 34228  ,  34216 , Count:  998
# Two Ports: 34228  ,  34226 , Count:  1013
# Two Ports: 34228  ,  33970 , Count:  983
# Two Ports: 34228  ,  33972 , Count:  956
# Two Ports: 34228  ,  34222 , Count:  711
# Two Ports: 34228  ,  34230 , Count:  697
# Two Ports: 34228  ,  33966 , Count:  677
# Two Ports: 34228  ,  33974 , Count:  644
# Two Ports: 33962  ,  33960 , Count:  1015
# Two Ports: 33962  ,  33964 , Count:  1000
# Two Ports: 33962  ,  34216 , Count:  1005
# Two Ports: 33962  ,  34226 , Count:  1042
# Two Ports: 33962  ,  33970 , Count:  1015
# Two Ports: 33962  ,  33972 , Count:  988
# Two Ports: 33962  ,  34222 , Count:  723
# Two Ports: 33962  ,  34230 , Count:  722
# Two Ports: 33962  ,  33966 , Count:  730
# Two Ports: 33962  ,  33974 , Count:  673
# Two Ports: 33960  ,  33964 , Count:  1005
# Two Ports: 33960  ,  34216 , Count:  999
# Two Ports: 33960  ,  34226 , Count:  1034
# Two Ports: 33960  ,  33970 , Count:  983
# Two Ports: 33960  ,  33972 , Count:  996
# Two Ports: 33960  ,  34222 , Count:  730
# Two Ports: 33960  ,  34230 , Count:  695
# Two Ports: 33960  ,  33966 , Count:  705
# Two Ports: 33960  ,  33974 , Count:  665
# Two Ports: 33964  ,  34216 , Count:  967
# Two Ports: 33964  ,  34226 , Count:  1004
# Two Ports: 33964  ,  33970 , Count:  993
# Two Ports: 33964  ,  33972 , Count:  960
# Two Ports: 33964  ,  34222 , Count:  692
# Two Ports: 33964  ,  34230 , Count:  691
# Two Ports: 33964  ,  33966 , Count:  669
# Two Ports: 33964  ,  33974 , Count:  650
# Two Ports: 34216  ,  34226 , Count:  1015
# Two Ports: 34216  ,  33970 , Count:  997
# Two Ports: 34216  ,  33972 , Count:  990
# Two Ports: 34216  ,  34222 , Count:  704
# Two Ports: 34216  ,  34230 , Count:  702
# Two Ports: 34216  ,  33966 , Count:  678
# Two Ports: 34216  ,  33974 , Count:  662
# Two Ports: 34226  ,  33970 , Count:  997
# Two Ports: 34226  ,  33972 , Count:  1023
# Two Ports: 34226  ,  34222 , Count:  712
# Two Ports: 34226  ,  34230 , Count:  702
# Two Ports: 34226  ,  33966 , Count:  707
# Two Ports: 34226  ,  33974 , Count:  679
# Two Ports: 33970  ,  33972 , Count:  971
# Two Ports: 33970  ,  34222 , Count:  725
# Two Ports: 33970  ,  34230 , Count:  685
# Two Ports: 33970  ,  33966 , Count:  678
# Two Ports: 33970  ,  33974 , Count:  644
# Two Ports: 33972  ,  34222 , Count:  717
# Two Ports: 33972  ,  34230 , Count:  694
# Two Ports: 33972  ,  33966 , Count:  657
# Two Ports: 33972  ,  33974 , Count:  639
# Two Ports: 34222  ,  33966 , Count:  515
# Two Ports: 34230  ,  33966 , Count:  525
# Two Ports: 22  ,  8291 , Count:  555
# Two Ports: 22  ,  8728 , Count:  511
# Two Ports: 8291  ,  8728 , Count:  521

# %% [markdown]
# # Create a PySpark DataFrame using the Pandas dataframes of frequent 2-port sets, then write the PySpark DataFrame (with header information)

# %%
DF2port = ss.createDataFrame(Two_Port_Sets_df)

# %%
output_path_2_port = "2PS_dfw5416_local.csv"
DF2port.write.option("header", True).csv(output_path_2_port)

# %% [markdown]
# # Part D Finding Frequent 3-port sets

# %% [markdown]
# # Approach 1:
# ## One way To find frequent 3-port sets is to add another nested loop, inside the two loops above, to iterate three all possible frequent 3 port sets.
# ```
# N = Total number of frequent 1-ports
# For top port index i from 0 to N-1 do:
#     filtered_MPscanner_Top_port_i = filter MPscanner_port_list_RDD for top port index i
#     For top port index j from i+1 to N-1 do:
#         filtered_MPscanner_Top_port_i_j = filter filtered_MPscanner_Top_port_i for top port index j
#         port_i_j_count = filtered_MPscanner_Top_port_i_j.count()
#         If port_i_j_count > threshold:
#             Save [ [Top_port[i], Top_port[j]] , port_i_j_count ] in a Pandas dataframe for frequent 2 port set
#             For top port index k from j+1 to N-1 do:
#                 filtered_MPscanner_Top_port_i_j_k = filter filtered_MPscanner_Top_port_i_j for top port index k
#                 port_i_j_k_count = filtered_MPscanner_Top_port_i_j_k.count()
#                 If port_i_j_k_count > threshold:
#                 Save [ [Top_port[i], Top_port[j], Top_port[k]], port_i_j_k_count ] in a Panda dataframe for frequent 3 port set
# ```

# %% [markdown]
# # A More Scalable Approach:
# ## Due to the big size of the data, finding frequent 3 port set as the 2nd nested loop inside the loop for finding frequent 2 port sets is costly because it needs to maintain persisting on two RDDs needed for the outer loop.  In addition, it needs to persist and unpersist scanners for a 2 port set that exceeds the threshold so that we can iterate through possible 3rd ports for finding frequent 3 port sets.
# ## An Alternative Approach is to find frequent 3 port sets AFTER we have found frequent 2-port sets so that we can reduce the number of RDDs that need to persist at the same time.
# ## Also, we can reduce the size of scanners to consider, because we can filter out scanners that scan less than 3 ports.
# ## Below is an algorithm:
# ```
# Read scanners data, parse the ports_scanned_str into an array
# Generate an RDD containinging the list of ports scanned by each scanner.
# Top_ports = A list of ports whose scanner count is > threshold
# candidate_3PS_scanners = filter scanners for those that scan at least 3 ports
# frequent_2PS_RDD = Reads from the file created from frequent 2 port set mining
# frequent_2PS_RDD.persisit()
# for each 2PS in frequent_2PS_RDD do:
#     scanners_2PS = filter candidate_3PS_scanners for those that scan the two port set 2PS
#     if the number of scanners in scanners_2PS > threshold:
#         scanners_2PS.persist()
#         index_i = index of first port in 2PS
#         index_j = index of second port in 2PS
#         for index_k from max{index_i, index_j} +1 to len(Top_ports) do:
#             scanners_3PS = filter scanners_2PS for Top_ports[index_k]
#             if the number of scanners in scanners_3PS > threshold:
#                 Record Top_ports[index_i], Top_ports[index_j], and Top_ports[index_k] as a frequent 3PortSet together with its count
#         scanners_2PS.unpersisit()
# frequent_2PS_RDD.unpersisit()
#
# ```

# %%
# If read from file, change this line to read from your cluster output
# TwoPS_DF = ss.read.csv("/storage/home/juy1/work/MiniProj1/2PS_juy1_local.csv", header=True, inferSchema=True)

# %%
DF2port_A = DF2port.withColumn("ports array", split("Port Sets", "-") )

# %%
DF2port_A.show(3)
# Out:
# +-----------+-----+--------------+
# |  Port Sets|count|   ports array|
# +-----------+-----+--------------+
# |17132-17140|16317|[17132, 17140]|
# |17132-17128|16279|[17132, 17128]|
# |17132-17138|16299|[17132, 17138]|
# +-----------+-----+--------------+
# only showing top 3 rows

# %%
DF2port_RDD = DF2port_A.select("ports array").rdd

# %%
DF2port_RDD.take(3)
# Out:
# [Row(ports array=['17132', '17140']),
#  Row(ports array=['17132', '17128']),
#  Row(ports array=['17132', '17138'])]

# %%
TwoPort_list = DF2port_RDD.map(lambda x: x["ports array"]).collect()

# %%
print(TwoPort_list)
# Out:
# [['17132', '17140'], ['17132', '17128'], ['17132', '17138'], ['17132', '17130'], ['17132', '17136'], ['17132', '17142'], ['17132', '17134'], ['17132', '34218'], ['17132', '34220'], ['17132', '33968'], ['17132', '34224'], ['17132', '34228'], ['17132', '33962'], ['17132', '33960'], ['17132', '33964'], ['17132', '34216'], ['17132', '34226'], ['17132', '33970'], ['17132', '33972'], ['17132', '34222'], ['17132', '34230'], ['17132', '33966'], ['17132', '33974'], ['17140', '17128'], ['17140', '17138'], ['17140', '17130'], ['17140', '17136'], ['17140', '17142'], ['17140', '17134'], ['17140', '34218'], ['17140', '34220'], ['17140', '33968'], ['17140', '34224'], ['17140', '34228'], ['17140', '33962'], ['17140', '33960'], ['17140', '33964'], ['17140', '34216'], ['17140', '34226'], ['17140', '33970'], ['17140', '33972'], ['17140', '34222'], ['17140', '34230'], ['17140', '33966'], ['17140', '33974'], ['17128', '17138'], ['17128', '17130'], ['17128', '17136'], ['17128', '17142'], ['17128', '17134'], ['17128', '34218'], ['17128', '34220'], ['17128', '33968'], ['17128', '34224'], ['17128', '34228'], ['17128', '33962'], ['17128', '33960'], ['17128', '33964'], ['17128', '34216'], ['17128', '34226'], ['17128', '33970'], ['17128', '33972'], ['17128', '34222'], ['17128', '34230'], ['17128', '33966'], ['17128', '33974'], ['17138', '17130'], ['17138', '17136'], ['17138', '17142'], ['17138', '17134'], ['17138', '34218'], ['17138', '34220'], ['17138', '33968'], ['17138', '34224'], ['17138', '34228'], ['17138', '33962'], ['17138', '33960'], ['17138', '33964'], ['17138', '34216'], ['17138', '34226'], ['17138', '33970'], ['17138', '33972'], ['17138', '34222'], ['17138', '34230'], ['17138', '33966'], ['17138', '33974'], ['17130', '17136'], ['17130', '17142'], ['17130', '17134'], ['17130', '34218'], ['17130', '34220'], ['17130', '33968'], ['17130', '34224'], ['17130', '34228'], ['17130', '33962'], ['17130', '33960'], ['17130', '33964'], ['17130', '34216'], ['17130', '34226'], ['17130', '33970'], ['17130', '33972'], ['17130', '34222'], ['17130', '34230'], ['17130', '33966'], ['17130', '33974'], ['17136', '17142'], ['17136', '17134'], ['17136', '34218'], ['17136', '34220'], ['17136', '33968'], ['17136', '34224'], ['17136', '34228'], ['17136', '33962'], ['17136', '33960'], ['17136', '33964'], ['17136', '34216'], ['17136', '34226'], ['17136', '33970'], ['17136', '33972'], ['17136', '34222'], ['17136', '34230'], ['17136', '33966'], ['17136', '33974'], ['23', '80'], ['23', '8080'], ['23', '2323'], ['23', '5555'], ['23', '81'], ['23', '1023'], ['23', '52869'], ['23', '8443'], ['23', '49152'], ['23', '7574'], ['23', '37215'], ['54594', '50401'], ['17142', '17134'], ['17142', '34218'], ['17142', '34220'], ['17142', '33968'], ['17142', '34224'], ['17142', '34228'], ['17142', '33962'], ['17142', '33960'], ['17142', '33964'], ['17142', '34216'], ['17142', '34226'], ['17142', '33970'], ['17142', '33972'], ['17142', '34222'], ['17142', '34230'], ['17142', '33966'], ['17142', '33974'], ['17134', '34218'], ['17134', '34220'], ['17134', '33968'], ['17134', '34224'], ['17134', '34228'], ['17134', '33962'], ['17134', '33960'], ['17134', '33964'], ['17134', '34216'], ['17134', '34226'], ['17134', '33970'], ['17134', '33972'], ['17134', '34222'], ['17134', '34230'], ['17134', '33966'], ['17134', '33974'], ['80', '8080'], ['80', '2323'], ['80', '5555'], ['80', '81'], ['80', '1023'], ['80', '52869'], ['80', '8443'], ['80', '49152'], ['80', '7574'], ['80', '37215'], ['8080', '2323'], ['8080', '5555'], ['8080', '81'], ['8080', '1023'], ['8080', '52869'], ['8080', '8443'], ['8080', '49152'], ['8080', '7574'], ['8080', '37215'], ['2323', '5555'], ['2323', '81'], ['2323', '1023'], ['2323', '52869'], ['2323', '8443'], ['2323', '49152'], ['2323', '7574'], ['2323', '37215'], ['5555', '81'], ['5555', '1023'], ['5555', '52869'], ['5555', '8443'], ['5555', '49152'], ['5555', '7574'], ['5555', '37215'], ['81', '1023'], ['81', '52869'], ['81', '8443'], ['81', '49152'], ['81', '7574'], ['81', ...

# %% [markdown]
# ## Filter Scanners for those that scan at least three ports

# %%
Candidate_3PS_scanners = MPscanner_port_list_RDD.filter(lambda x: len(x) >= 3)

# %%
Candidate_3PS_scanners.persist()
# Out:
# PythonRDD[1235] at RDD at PythonRDD.scala:53

# %%
MPscanner_port_list_RDD.unpersist()
# Out:
# PythonRDD[43] at RDD at PythonRDD.scala:53

# %% [markdown]
# # Problem 7 (15 points)
# ## Complete the missing code (including persist and unpersist) below for mining frequent 3 port sets
# ## and write the results (three port sets and their counts) using PySpark DataFrame.

# %%
# Initialize a Pandas DataFrame to store frequent port sets and their counts 
Three_Port_Sets_df = pd.DataFrame( columns= ['Port Sets', 'count'])
# Initialize the index to Three_Port_Sets_df
index3 = 0
# Set the threshold for Frequent Port Sets to be 400 in local mode.
# This threshold needs to be changed to 10000 in the cluster mode.
threshold = 500
Top_1_Port_count = len(Top_Ports)
for TwoPS in TwoPort_list:
    index_i = Top_Ports.index( TwoPS[0] )
    index_j = Top_Ports.index( TwoPS[1] )
    filtered_scanners_i_j = Candidate_3PS_scanners.filter(lambda x: Top_Ports[index_i] in x).filter(lambda y: Top_Ports[index_j] in y)
    filtered_scanners_i_j.persist()  
    for k in range(max(index_i, index_j)+1, Top_1_Port_count):
        filtered_scanners_i_j_k = filtered_scanners_i_j.filter(lambda x: Top_Ports[k] in x)
        port_i_j_k_count = filtered_scanners_i_j_k.count()
        if port_i_j_k_count > threshold:
            Three_Port_Sets_df.loc[index3] = [ Top_Ports[index_i]+"-"+Top_Ports[index_j]+"-"+Top_Ports[k], port_i_j_k_count] 
            index3 = index3 + 1
            # The print statement is for running in the local mode.  It can be commented out for running in the cluster mode.
            print("Three Ports:", Top_Ports[index_i], " , ", Top_Ports[index_j], " , ", Top_Ports[k], ", Count: ", port_i_j_k_count)
    filtered_scanners_i_j.unpersist()
# Out:
# Three Ports: 17132  ,  17140  ,  17128 , Count:  12594
# Three Ports: 17132  ,  17140  ,  17138 , Count:  12562
# Three Ports: 17132  ,  17140  ,  17130 , Count:  12665
# Three Ports: 17132  ,  17140  ,  17136 , Count:  12522
# Three Ports: 17132  ,  17140  ,  17142 , Count:  10461
# Three Ports: 17132  ,  17140  ,  17134 , Count:  10454
# Three Ports: 17132  ,  17140  ,  34218 , Count:  2463
# Three Ports: 17132  ,  17140  ,  34220 , Count:  2453
# Three Ports: 17132  ,  17140  ,  33968 , Count:  2420
# Three Ports: 17132  ,  17140  ,  34224 , Count:  2461
# Three Ports: 17132  ,  17140  ,  34228 , Count:  2443
# Three Ports: 17132  ,  17140  ,  33962 , Count:  2397
# Three Ports: 17132  ,  17140  ,  33960 , Count:  2413
# Three Ports: 17132  ,  17140  ,  33964 , Count:  2361
# Three Ports: 17132  ,  17140  ,  34216 , Count:  2359
# Three Ports: 17132  ,  17140  ,  34226 , Count:  2382
# Three Ports: 17132  ,  17140  ,  33970 , Count:  2334
# Three Ports: 17132  ,  17140  ,  33972 , Count:  2391
# Three Ports: 17132  ,  17140  ,  34222 , Count:  1536
# Three Ports: 17132  ,  17140  ,  34230 , Count:  1493
# Three Ports: 17132  ,  17140  ,  33966 , Count:  1506
# Three Ports: 17132  ,  17140  ,  33974 , Count:  1398
# Three Ports: 17132  ,  17128  ,  17138 , Count:  12533
# Three Ports: 17132  ,  17128  ,  17130 , Count:  12640
# Three Ports: 17132  ,  17128  ,  17136 , Count:  12566
# Three Ports: 17132  ,  17128  ,  17142 , Count:  10421
# Three Ports: 17132  ,  17128  ,  17134 , Count:  10490
# Three Ports: 17132  ,  17128  ,  34218 , Count:  2478
# Three Ports: 17132  ,  17128  ,  34220 , Count:  2456
# Three Ports: 17132  ,  17128  ,  33968 , Count:  2428
# Three Ports: 17132  ,  17128  ,  34224 , Count:  2443
# Three Ports: 17132  ,  17128  ,  34228 , Count:  2436
# Three Ports: 17132  ,  17128  ,  33962 , Count:  2423
# Three Ports: 17132  ,  17128  ,  33960 , Count:  2439
# Three Ports: 17132  ,  17128  ,  33964 , Count:  2368
# Three Ports: 17132  ,  17128  ,  34216 , Count:  2381
# Three Ports: 17132  ,  17128  ,  34226 , Count:  2391
# Three Ports: 17132  ,  17128  ,  33970 , Count:  2344
# Three Ports: 17132  ,  17128  ,  33972 , Count:  2391
# Three Ports: 17132  ,  17128  ,  34222 , Count:  1531
# Three Ports: 17132  ,  17128  ,  34230 , Count:  1486
# Three Ports: 17132  ,  17128  ,  33966 , Count:  1501
# Three Ports: 17132  ,  17128  ,  33974 , Count:  1388
# Three Ports: 17132  ,  17138  ,  17130 , Count:  12590
# Three Ports: 17132  ,  17138  ,  17136 , Count:  12469
# Three Ports: 17132  ,  17138  ,  17142 , Count:  10404
# Three Ports: 17132  ,  17138  ,  17134 , Count:  10472
# Three Ports: 17132  ,  17138  ,  34218 , Count:  2472
# Three Ports: 17132  ,  17138  ,  34220 , Count:  2433
# Three Ports: 17132  ,  17138  ,  33968 , Count:  2411
# Three Ports: 17132  ,  17138  ,  34224 , Count:  2424
# Three Ports: 17132  ,  17138  ,  34228 , Count:  2415
# Three Ports: 17132  ,  17138  ,  33962 , Count:  2390
# Three Ports: 17132  ,  17138  ,  33960 , Count:  2440
# Three Ports: 17132  ,  17138  ,  33964 , Count:  2365
# Three Ports: 17132  ,  17138  ,  34216 , Count:  2371
# Three Ports: 17132  ,  17138  ,  34226 , Count:  2408
# Three Ports: 17132  ,  17138  ,  33970 , Count:  2368
# Three Ports: 17132  ,  17138  ,  33972 , Count:  2392
# Three Ports: 17132  ,  17138  ,  34222 , Count:  1525
# Three Ports: 17132  ,  17138  ,  34230 , Count:  1490
# Three Ports: 17132  ,  17138  ,  33966 , Count:  1486
# Three Ports: 17132  ,  17138  ,  33974 , Count:  1388
# Three Ports: 17132  ,  17130  ,  17136 , Count:  12578
# Three Ports: 17132  ,  17130  ,  17142 , Count:  10425
# Three Ports: 17132  ,  17130  ,  17134 , Count:  10498
# Three Ports: 17132  ,  17130  ,  34218 , Count:  2492
# Three Ports: 17132  ,  17130  ,  34220 , Count:  2443
# Three Ports: 17132  ,  17130  ,  33968 , Count:  2428
# Three Ports: 17132  ,  17130  ,  34224 , Count:  2438
# Three Ports: 17132  ,  17130  ,  34228 , Count:  2404
# Three Ports: 17132  ,  17130  ,  33962 , Count:  2424
# Three Ports: 17132  ,  17130  ,  33960 , Count:  2432
# Three Ports: 17132  ,  17130  ,  33964 , Count:  2359
# Three Ports: 17132  ,  17130  ,  34216 , Count:  2356
# Three Ports: 17132  ,  17130  ,  34226 , Count:  2384
# Three Ports: 17132  ,  17130  ,  33970 , Count:  2378
# Three Ports: 17132  ,  17130  ,  33972 , Count:  2372
# Three Ports: 17132  ,  17130  ,  34222 , Count:  1517
# Three Ports: 17132  ,  17130  ,  34230 , Count:  1489
# Three Ports: 17132  ,  17130  ,  33966 , Count:  1495
# Three Ports: 17132  ,  17130  ,  33974 , Count:  1392
# Three Ports: 17132  ,  17136  ,  17142 , Count:  10371
# Three Ports: 17132  ,  17136  ,  17134 , Count:  10444
# Three Ports: 17132  ,  17136  ,  34218 , Count:  2462
# Three Ports: 17132  ,  17136  ,  34220 , Count:  2448
# Three Ports: 17132  ,  17136  ,  33968 , Count:  2424
# Three Ports: 17132  ,  17136  ,  34224 , Count:  2441
# Three Ports: 17132  ,  17136  ,  34228 , Count:  2422
# Three Ports: 17132  ,  17136  ,  33962 , Count:  2419
# Three Ports: 17132  ,  17136  ,  33960 , Count:  2439
# Three Ports: 17132  ,  17136  ,  33964 , Count:  2375
# Three Ports: 17132  ,  17136  ,  34216 , Count:  2387
# Three Ports: 17132  ,  17136  ,  34226 , Count:  2395
# Three Ports: 17132  ,  17136  ,  33970 , Count:  2345
# Three Ports: 17132  ,  17136  ,  33972 , Count:  2379
# Three Ports: 17132  ,  17136  ,  34222 , Count:  1521
# Three Ports: 17132  ,  17136  ,  34230 , Count:  1491
# Three Ports: 17132  ,  17136  ,  33966 , Count:  1494
# Three Ports: 17132  ,  17136  ,  33974 , Count:  1390
# Three Ports: 17132  ,  17142  ,  17134 , Count:  8930
# Three Ports: 17132  ,  17142  ,  34218 , Count:  2299
# Three Ports: 17132  ,  17142  ,  34220 , Count:  2258
# Three Ports: 17132  ,  17142  ,  33968 , Count:  2263
# Three Ports: 17132  ,  17142  ,  34224 , Count:  2293
# Three Ports: 17132  ,  17142  ,  34228 , Count:  2264
# Three Ports: 17132  ,  17142  ,  33962 , Count:  2254
# Three Ports: 17132  ,  17142  ,  33960 , Count:  2263
# Three Ports: 17132  ,  17142  ,  33964 , Count:  2187
# Three Ports: 17132  ,  17142  ,  34216 , Count:  2202
# Three Ports: 17132  ,  17142  ,  34226 , Count:  2218
# Three Ports: 17132  ,  17142  ,  33970 , Count:  2216
# Three Ports: 17132  ,  17142  ,  33972 , Count:  2210
# Three Ports: 17132  ,  17142  ,  34222 , Count:  1444
# Three Ports: 17132  ,  17142  ,  34230 , Count:  1405
# Three Ports: 17132  ,  17142  ,  33966 , Count:  1418
# Three Ports: 17132  ,  17142  ,  33974 , Count:  1300
# Three Ports: 17132  ,  17134  ,  34218 , Count:  2315
# Three Ports: 17132  ,  17134  ,  34220 , Count:  2295
# Three Ports: 17132  ,  17134  ,  33968 , Count:  2263
# Three Ports: 17132  ,  17134  ,  34224 , Count:  2282
# Three Ports: 17132  ,  17134  ,  34228 , Count:  2252
# Three Ports: 17132  ,  17134  ,  33962 , Count:  2241
# Three Ports: 17132  ,  17134  ,  33960 , Count:  2262
# Three Ports: 17132  ,  17134  ,  33964 , Count:  2186
# Three Ports: 17132  ,  17134  ,  34216 , Count:  2222
# Three Ports: 17132  ,  17134  ,  34226 , Count:  2259
# Three Ports: 17132  ,  17134  ,  33970 , Count:  2191
# Three Ports: 17132  ,  17134  ,  33972 , Count:  2207
# Three Ports: 17132  ,  17134  ,  34222 , Count:  1459
# Three Ports: 17132  ,  17134  ,  34230 , Count:  1404
# Three Ports: 17132  ,  17134  ,  33966 , Count:  1420
# Three Ports: 17132  ,  17134  ,  33974 , Count:  1320
# Three Ports: 17132  ,  34218  ,  34220 , Count:  1008
# Three Ports: 17132  ,  34218  ,  33968 , Count:  1031
# Three Ports: 17132  ,  34218  ,  34224 , Count:  1076
# Three Ports: 17132  ,  34218  ,  34228 , Count:  985
# Three Ports: 17132  ,  34218  ,  33962 , Count:  1025
# Three Ports: 17132  ,  34218  ,  33960 , Count:  1012
# Three Ports: 17132  ,  34218  ,  33964 , Count:  981
# Three Ports: 17132  ,  34218  ,  34216 , Count:  994
# Three Ports: 17132  ,  34218  ,  34226 , Count:  1016
# Three Ports: 17132  ,  34218  ,  33970 , Count:  995
# Three Ports: 17132  ,  34218  ,  33972 , Count:  976
# Three Ports: 17132  ,  34218  ,  34222 , Count:  718
# Three Ports: 17132  ,  34218  ,  34230 , Count:  692
# Three Ports: 17132  ,  34218  ,  33966 , Count:  703
# Three Ports: 17132  ,  34218  ,  33974 , Count:  658
# Three Ports: 17132  ,  34220  ,  33968 , Count:  1024
# Three Ports: 17132  ,  34220  ,  34224 , Count:  1039
# Three Ports: 17132  ,  34220  ,  34228 , Count:  990
# Three Ports: 17132  ,  34220  ,  33962 , Count:  1006
# Three Ports: 17132  ,  34220  ,  33960 , Count:  990
# Three Ports: 17132  ,  34220  ,  33964 , Count:  1005
# Three Ports: 17132  ,  34220  ,  34216 , Count:  976
# Three Ports: 17132  ,  34220  ,  34226 , Count:  1005
# Three Ports: 17132  ,  34220  ,  33970 , Count:  970
# Three Ports: 17132  ,  34220  ,  33972 , Count:  980
# Three Ports: 17132  ,  34220  ,  34222 , Count:  740
# Three Ports: 17132  ,  34220  ,  34230 , Count:  690
# Three Ports: 17132  ,  34220  ,  33966 , Count:  697
# Three Ports: 17132  ,  34220  ,  33974 , Count:  654
# Three Ports: 17132  ,  33968  ,  34224 , Count:  1030
# Three Ports: 17132  ,  33968  ,  34228 , Count:  991
# Three Ports: 17132  ,  33968  ,  33962 , Count:  1001
# Three Ports: 17132  ,  33968  ,  33960 , Count:  1025
# Three Ports: 17132  ,  33968  ,  33964 , Count:  991
# Three Ports: 17132  ,  33968  ,  34216 , Count:  1002
# Three Ports: 17132  ,  33968  ,  34226 , Count:  1010
# Three Ports: 17132  ,  33968  ,  33970 , Count:  992
# Three Ports: 17132  ,  33968  ,  33972 , Count:  974
# Three Ports: 17132  ,  33968  ,  34222 , Count:  720
# Three Ports: 17132  ,  33968  ,  34230 , Count:  694
# Three Ports: 17132  ,  33968  ,  33966 , Count:  689
# Three Ports: 17132  ,  33968  ,  33974 , Count:  656
# Three Ports: 17132  ,  34224  ,  34228 , Count:  1004
# Three Ports: 17132  ,  34224  ,  33962 , Count:  1010
# Three Ports: 17132  ,  34224  ,  33960 , Count:  1017
# Three Ports: 17132  ,  34224  ,  33964 , Count:  988
# Three Ports: 17132  ,  34224  ,  34216 , Count:  1009
# Three Ports: 17132  ,  34224  ,  34226 , Count:  1020
# Three Ports: 17132  ,  34224  ,  33970 , Count:  998
# Three Ports: 17132  ,  34224  ,  33972 , Count:  1006
# Three Ports: 17132  ,  34224  ,  34222 , Count:  728
# Three Ports: 17132  ,  34224  ,  34230 , Count:  688
# Three Ports: 17132  ,  34224  ,  33966 , Count:  710
# Three Ports: 17132  ,  34224  ,  33974 , Count:  650
# Three Ports: 17132  ,  34228  ,  33962 , Count:  1011
# Three Ports: 17132  ,  34228  ,  33960 , Count:  973
# Three Ports: 17132  ,  34228  ,  33964 , Count:  973
# Three Ports: 17132  ,  34228  ,  34216 , Count:  991
# Three Ports: 17132  ,  34228  ,  34226 , Count:  995
# Three Ports: 17132  ,  34228  ,  33970 , Count:  964
# Three Ports: 17132  ,  34228  ,  33972 , Count:  945
# Three Ports: 17132  ,  34228  ,  34222 , Count:  704
# Three Ports: 17132  ,  34228  ,  34230 , Count:  685
# Three Ports: 17132  ,  34228  ,  33966 , Count:  670
# Three Ports: 17132  ,  34228  ,  33974 , Count:  633
# Three Ports: 17132  ,  33962  ,  33960 , Count:  1006
# Three Ports: 17132  ,  33962  ,  33964 , Count:  985
# Three Ports: 17132  ,  33962  ,  34216 , Count:  993
# Three Ports: 17132  ,  33962  ,  34226 , Count:  1029
# Three Ports: 17132  ,  33962  ,  33970 , Count:  1001
# Three Ports: 17132  ,  33962  ,  33972 , Count:  969
# Three Ports: 17132  ,  33962  ,  34222 , Count:  719
# Three Ports: 17132  ,  33962  ,  34230 , Count:  706
# Three Ports: 17132  ,  33962  ,  33966 , Count:  720
# Three Ports: 17132  ,  33962  ,  33974 , Count:  664
# Three Ports: 17132  ,  33960  ,  33964 , Count:  998
# Three Ports: 17132  ,  33960  ,  34216 , Count:  986
# Three Ports: 17132  ,  33960  ,  34226 , Count:  1025
# Three Ports: 17132  ,  33960  ,  33970 , Count:  973
# Three Ports: 17132  ,  33960  ,  33972 , Count:  987
# Three Ports: 17132  ,  33960  ,  34222 , Count:  724
# Three Ports: 17132  ,  33960  ,  34230 , Count:  686
# Three Ports: 17132  ,  33960  ,  33966 , Count:  700
# Three Ports: 17132  ,  33960  ,  33974 , Count:  659
# Three Ports: 17132  ,  33964  ,  34216 , Count:  957
# Three Ports: 17132  ,  33964  ,  34226 , Count:  990
# Three Ports: 17132  ,  33964  ,  33970 , Count:  983
# Three Ports: 17132  ,  33964  ,  33972 , Count:  951
# Three Ports: 17132  ,  33964  ,  34222 , Count:  684
# Three Ports: 17132  ,  33964  ,  34230 , Count:  678
# Three Ports: 17132  ,  33964  ,  33966 , Count:  666
# Three Ports: 17132  ,  33964  ,  33974 , Count:  647
# Three Ports: 17132  ,  34216  ,  34226 , Count:  1006
# Three Ports: 17132  ,  34216  ,  33970 , Count:  987
# Three Ports: 17132  ,  34216  ,  33972 , Count:  974
# Three Ports: 17132  ,  34216  ,  34222 , Count:  694
# Three Ports: 17132  ,  34216  ,  34230 , Count:  694
# Three Ports: 17132  ,  34216  ,  33966 , Count:  675
# Three Ports: 17132  ,  34216  ,  33974 , Count:  656
# Three Ports: 17132  ,  34226  ,  33970 , Count:  986
# Three Ports: 17132  ,  34226  ,  33972 , Count:  1014
# Three Ports: 17132  ,  34226  ,  34222 , Count:  705
# Three Ports: 17132  ,  34226  ,  34230 , Count:  696
# Three Ports: 17132  ,  34226  ,  33966 , Count:  697
# Three Ports: 17132  ,  34226  ,  33974 , Count:  672
# Three Ports: 17132  ,  33970  ,  33972 , Count:  953
# Three Ports: 17132  ,  33970  ,  34222 , Count:  720
# Three Ports: 17132  ,  33970  ,  34230 , Count:  674
# Three Ports: 17132  ,  33970  ,  33966 , Count:  673
# Three Ports: 17132  ,  33970  ,  33974 , Count:  635
# Three Ports: 17132  ,  33972  ,  34222 , Count:  712
# Three Ports: 17132  ,  33972  ,  34230 , Count:  685
# Three Ports: 17132  ,  33972  ,  33966 , Count:  652
# Three Ports: 17132  ,  33972  ,  33974 , Count:  629
# Three Ports: 17132  ,  34222  ,  33966 , Count:  508
# Three Ports: 17132  ,  34230  ,  33966 , Count:  521
# Three Ports: 17140  ,  17128  ,  17138 , Count:  12404
# Three Ports: 17140  ,  17128  ,  17130 , Count:  12562
# Three Ports: 17140  ,  17128  ,  17136 , Count:  12501
# Three Ports: 17140  ,  17128  ,  17142 , Count:  10434
# Three Ports: 17140  ,  17128  ,  17134 , Count:  10376
# Three Ports: 17140  ,  17128  ,  34218 , Count:  2478
# Three Ports: 17140  ,  17128  ,  34220 , Count:  2435
# Three Ports: 17140  ,  17128  ,  33968 , Count:  2446
# Three Ports: 17140  ,  17128  ,  34224 , Count:  2442
# Three Ports: 17140  ,  17128  ,  34228 , Count:  2438
# Three Ports: 17140  ,  17128  ,  33962 , Count:  2439
# Three Ports: 17140  ,  17128  ,  33960 , Count:  2406
# Three Ports: 17140  ,  17128  ,  33964 , Count:  2351
# Three Ports: 17140  ,  17128  ,  34216 , Count:  2370
# Three Ports: 17140  ,  17128  ,  34226 , Count:  2364
# Three Ports: 17140  ,  17128  ,  33970 , Count:  2337
# Three Ports: 17140  ,  17128  ,  33972 , Count:  2384
# Three Ports: 17140  ,  17128  ,  34222 , Count:  1545
# Three Ports: 17140  ,  17128  ,  34230 , Count:  1486
# Three Ports: 17140  ,  17128  ,  33966 , Count:  1497
# Three Ports: 17140  ,  17128  ,  33974 , Count:  1397
# Three Ports: 17140  ,  17138  ,  17130 , Count:  12550
# Three Ports: 17140  ,  17138  ,  17136 , Count:  12430
# Three Ports: 17140  ,  17138  ,  17142 , Count:  10400
# Three Ports: 17140  ,  17138  ,  17134 , Count:  10372
# Three Ports: 17140  ,  17138  ,  34218 , Count:  2451
# Three Ports: 17140  ,  17138  ,  34220 , Count:  2414
# Three Ports: 17140  ,  17138  ,  33968 , Count:  2420
# Three Ports: 17140  ,  17138  ,  34224 , Count:  2434
# Three Ports: 17140  ,  17138  ,  34228 , Count:  2416
# Three Ports: 17140  ,  17138  ,  33962 , Count:  2410
# Three Ports: 17140  ,  17138  ,  33960 , Count:  2404
# Three Ports: 17140  ,  17138  ,  33964 , Count:  2346
# Three Ports: 17140  ,  17138  ,  34216 , Count:  2364
# Three Ports: 17140  ,  17138  ,  34226 , Count:  2391
# Three Ports: 17140  ,  17138  ,  33970 , Count:  2353
# Three Ports: 17140  ,  17138  ,  33972 , Count:  2386
# Three Ports: 17140  ,  17138  ,  34222 , Count:  1537
# Three Ports: 17140  ,  17138  ,  34230 , Count:  1480
# Three Ports: 17140  ,  17138  ,  33966 , Count:  1478
# Three Ports: 17140  ,  17138  ,  33974 , Count:  1399
# Three Ports: 17140  ,  17130  ,  17136 , Count:  12511
# Three Ports: 17140  ,  17130  ,  17142 , Count:  10438
# Three Ports: 17140  ,  17130  ,  17134 , Count:  10443
# Three Ports: 17140  ,  17130  ,  34218 , Count:  2474
# Three Ports: 17140  ,  17130  ,  34220 , Count:  2423
# Three Ports: 17140  ,  17130  ,  33968 , Count:  2439
# Three Ports: 17140  ,  17130  ,  34224 , Count:  2449
# Three Ports: 17140  ,  17130  ,  34228 , Count:  2412
# Three Ports: 17140  ,  17130  ,  33962 , Count:  2427
# Three Ports: 17140  ,  17130  ,  33960 , Count:  2402
# Three Ports: 17140  ,  17130  ,  33964 , Count:  2353
# Three Ports: 17140  ,  17130  ,  34216 , Count:  2345
# Three Ports: 17140  ,  17130  ,  34226 , Count:  2369
# Three Ports: 17140  ,  17130  ,  33970 , Count:  2358
# Three Ports: 17140  ,  17130  ,  33972 , Count:  2371
# Three Ports: 17140  ,  17130  ,  34222 , Count:  1532
# Three Ports: 17140  ,  17130  ,  34230 , Count:  1491
# Three Ports: 17140  ,  17130  ,  33966 , Count:  1487
# Three Ports: 17140  ,  17130  ,  33974 , Count:  1409
# Three Ports: 17140  ,  17136  ,  17142 , Count:  10352
# Three Ports: 17140  ,  17136  ,  17134 , Count:  10395
# Three Ports: 17140  ,  17136  ,  34218 , Count:  2445
# Three Ports: 17140  ,  17136  ,  34220 , Count:  2418
# Three Ports: 17140  ,  17136  ,  33968 , Count:  2430
# Three Ports: 17140  ,  17136  ,  34224 , Count:  2442
# Three Ports: 17140  ,  17136  ,  34228 , Count:  2415
# Three Ports: 17140  ,  17136  ,  33962 , Count:  2417
# Three Ports: 17140  ,  17136  ,  33960 , Count:  2404
# Three Ports: 17140  ,  17136  ,  33964 , Count:  2357
# Three Ports: 17140  ,  17136  ,  34216 , Count:  2371
# Three Ports: 17140  ,  17136  ,  34226 , Count:  2370
# Three Ports: 17140  ,  17136  ,  33970 , Count:  2332
# Three Ports: 17140  ,  17136  ,  33972 , Count:  2371
# Three Ports: 17140  ,  17136  ,  34222 , Count:  1522
# Three Ports: 17140  ,  17136  ,  34230 , Count:  1487
# Three Ports: 17140  ,  17136  ,  33966 , Count:  1485
# Three Ports: 17140  ,  17136  ,  33974 , Count:  1396
# Three Ports: 17140  ,  17142  ,  17134 , Count:  8883
# Three Ports: 17140  ,  17142  ,  34218 , Count:  2282
# Three Ports: 17140  ,  17142  ,  34220 , Count:  2234
# Three Ports: 17140  ,  17142  ,  33968 , Count:  2267
# Three Ports: 17140  ,  17142  ,  34224 , Count:  2302
# Three Ports: 17140  ,  17142  ,  34228 , Count:  2263
# Three Ports: 17140  ,  17142  ,  33962 , Count:  2263
# Three Ports: 17140  ,  17142  ,  33960 , Count:  2240
# Three Ports: 17140  ,  17142  ,  33964 , Count:  2186
# Three Ports: 17140  ,  17142  ,  34216 , Count:  2199
# Three Ports: 17140  ,  17142  ,  34226 , Count:  2218
# Three Ports: 17140  ,  17142  ,  33970 , Count:  2177
# Three Ports: 17140  ,  17142  ,  33972 , Count:  2212
# Three Ports: 17140  ,  17142  ,  34222 , Count:  1454
# Three Ports: 17140  ,  17142  ,  34230 , Count:  1410
# Three Ports: 17140  ,  17142  ,  33966 , Count:  1413
# Three Ports: 17140  ,  17142  ,  33974 , Count:  1308
# Three Ports: 17140  ,  17134  ,  34218 , Count:  2301
# Three Ports: 17140  ,  17134  ,  34220 , Count:  2277
# Three Ports: 17140  ,  17134  ,  33968 , Count:  2262
# Three Ports: 17140  ,  17134  ,  34224 , Count:  2288
# Three Ports: 17140  ,  17134  ,  34228 , Count:  2251
# Three Ports: 17140  ,  17134  ,  33962 , Count:  2256
# Three Ports: 17140  ,  17134  ,  33960 , Count:  2247
# Three Ports: 17140  ,  17134  ,  33964 , Count:  2180
# Three Ports: 17140  ,  17134  ,  34216 , Count:  2216
# Three Ports: 17140  ,  17134  ,  34226 , Count:  2247
# Three Ports: 17140  ,  17134  ,  33970 , Count:  2172
# Three Ports: 17140  ,  17134  ,  33972 , Count:  2212
# Three Ports: 17140  ,  17134  ,  34222 , Count:  1459
# Three Ports: 17140  ,  17134  ,  34230 , Count:  1406
# Three Ports: 17140  ,  17134  ,  33966 , Count:  1410
# Three Ports: 17140  ,  17134  ,  33974 , Count:  1321
# Three Ports: 17140  ,  34218  ,  34220 , Count:  1001
# Three Ports: 17140  ,  34218  ,  33968 , Count:  1032
# Three Ports: 17140  ,  34218  ,  34224 , Count:  1076
# Three Ports: 17140  ,  34218  ,  34228 , Count:  984
# Three Ports: 17140  ,  34218  ,  33962 , Count:  1024
# Three Ports: 17140  ,  34218  ,  33960 , Count:  1007
# Three Ports: 17140  ,  34218  ,  33964 , Count:  979
# Three Ports: 17140  ,  34218  ,  34216 , Count:  991
# Three Ports: 17140  ,  34218  ,  34226 , Count:  1012
# Three Ports: 17140  ,  34218  ,  33970 , Count:  990
# Three Ports: 17140  ,  34218  ,  33972 , Count:  975
# Three Ports: 17140  ,  34218  ,  34222 , Count:  714
# Three Ports: 17140  ,  34218  ,  34230 , Count:  687
# Three Ports: 17140  ,  34218  ,  33966 , Count:  695
# Three Ports: 17140  ,  34218  ,  33974 , Count:  655
# Three Ports: 17140  ,  34220  ,  33968 , Count:  1023
# Three Ports: 17140  ,  34220  ,  34224 , Count:  1032
# Three Ports: 17140  ,  34220  ,  34228 , Count:  983
# Three Ports: 17140  ,  34220  ,  33962 , Count:  1002
# Three Ports: 17140  ,  34220  ,  33960 , Count:  984
# Three Ports: 17140  ,  34220  ,  33964 , Count:  995
# Three Ports: 17140  ,  34220  ,  34216 , Count:  971
# Three Ports: 17140  ,  34220  ,  34226 , Count:  993
# Three Ports: 17140  ,  34220  ,  33970 , Count:  967
# Three Ports: 17140  ,  34220  ,  33972 , Count:  975
# Three Ports: 17140  ,  34220  ,  34222 , Count:  744
# Three Ports: 17140  ,  34220  ,  34230 , Count:  686
# Three Ports: 17140  ,  34220  ,  33966 , Count:  693
# Three Ports: 17140  ,  34220  ,  33974 , Count:  653
# Three Ports: 17140  ,  33968  ,  34224 , Count:  1035
# Three Ports: 17140  ,  33968  ,  34228 , Count:  994
# Three Ports: 17140  ,  33968  ,  33962 , Count:  998
# Three Ports: 17140  ,  33968  ,  33960 , Count:  1018
# Three Ports: 17140  ,  33968  ,  33964 , Count:  992
# Three Ports: 17140  ,  33968  ,  34216 , Count:  995
# Three Ports: 17140  ,  33968  ,  34226 , Count:  1009
# Three Ports: 17140  ,  33968  ,  33970 , Count:  990
# Three Ports: 17140  ,  33968  ,  33972 , Count:  979
# Three Ports: 17140  ,  33968  ,  34222 , Count:  721
# Three Ports: 17140  ,  33968  ,  34230 , Count:  693
# Three Ports: 17140  ,  33968  ,  33966 , Count:  686
# Three Ports: 17140  ,  33968  ,  33974 , Count:  653
# Three Ports: 17140  ,  34224  ,  34228 , Count:  999
# Three Ports: 17140  ,  34224  ,  33962 , Count:  1012
# Three Ports: 17140  ,  34224  ,  33960 , Count:  1014
# Three Ports: 17140  ,  34224  ,  33964 , Count:  991
# Three Ports: 17140  ,  34224  ,  34216 , Count:  1007
# Three Ports: 17140  ,  34224  ,  34226 , Count:  1015
# Three Ports: 17140  ,  34224  ,  33970 , Count:  996
# Three Ports: 17140  ,  34224  ,  33972 , Count:  1004
# Three Ports: 17140  ,  34224  ,  34222 , Count:  719
# Three Ports: 17140  ,  34224  ,  34230 , Count:  684
# Three Ports: 17140  ,  34224  ,  33966 , Count:  708
# Three Ports: 17140  ,  34224  ,  33974 , Count:  644
# Three Ports: 17140  ,  34228  ,  33962 , Count:  1005
# Three Ports: 17140  ,  34228  ,  33960 , Count:  971
# Three Ports: 17140  ,  34228  ,  33964 , Count:  970
# Three Ports: 17140  ,  34228  ,  34216 , Count:  981
# Three Ports: 17140  ,  34228  ,  34226 , Count:  993
# Three Ports: 17140  ,  34228  ,  33970 , Count:  969
# Three Ports: 17140  ,  34228  ,  33972 , Count:  941
# Three Ports: 17140  ,  34228  ,  34222 , Count:  704
# Three Ports: 17140  ,  34228  ,  34230 , Count:  691
# Three Ports: 17140  ,  34228  ,  33966 , Count:  669
# Three Ports: 17140  ,  34228  ,  33974 , Count:  636
# Three Ports: 17140  ,  33962  ,  33960 , Count:  992
# Three Ports: 17140  ,  33962  ,  33964 , Count:  993
# Three Ports: 17140  ,  33962  ,  34216 , Count:  985
# Three Ports: 17140  ,  33962  ,  34226 , Count:  1023
# Three Ports: 17140  ,  33962  ,  33970 , Count:  997
# Three Ports: 17140  ,  33962  ,  33972 , Count:  972
# Three Ports: 17140  ,  33962  ,  34222 , Count:  713
# Three Ports: 17140  ,  33962  ,  34230 , Count:  706
# Three Ports: 17140  ,  33962  ,  33966 , Count:  715
# Three Ports: 17140  ,  33962  ,  33974 , Count:  659
# Three Ports: 17140  ,  33960  ,  33964 , Count:  992
# Three Ports: 17140  ,  33960  ,  34216 , Count:  978
# Three Ports: 17140  ,  33960  ,  34226 , Count:  1015
# Three Ports: 17140  ,  33960  ,  33970 , Count:  961
# Three Ports: 17140  ,  33960  ,  33972 , Count:  977
# Three Ports: 17140  ,  33960  ,  34222 , Count:  718
# Three Ports: 17140  ,  33960  ,  34230 , Count:  684
# Three Ports: 17140  ,  33960  ,  33966 , Count:  694
# Three Ports: 17140  ,  33960  ,  33974 , Count:  655
# Three Ports: 17140  ,  33964  ,  34216 , Count:  956
# Three Ports: 17140  ,  33964  ,  34226 , Count:  985
# Three Ports: 17140  ,  33964  ,  33970 , Count:  982
# Three Ports: 17140  ,  33964  ,  33972 , Count:  945
# Three Ports: 17140  ,  33964  ,  34222 , Count:  687
# Three Ports: 17140  ,  33964  ,  34230 , Count:  674
# Three Ports: 17140  ,  33964  ,  33966 , Count:  668
# Three Ports: 17140  ,  33964  ,  33974 , Count:  643
# Three Ports: 17140  ,  34216  ,  34226 , Count:  1001
# Three Ports: 17140  ,  34216  ,  33970 , Count:  975
# Three Ports: 17140  ,  34216  ,  33972 , Count:  966
# Three Ports: 17140  ,  34216  ,  34222 , Count:  693
# Three Ports: 17140  ,  34216  ,  34230 , Count:  694
# Three Ports: 17140  ,  34216  ,  33966 , Count:  668
# Three Ports: 17140  ,  34216  ,  33974 , Count:  649
# Three Ports: 17140  ,  34226  ,  33970 , Count:  985
# Three Ports: 17140  ,  34226  ,  33972 , Count:  1012
# Three Ports: 17140  ,  34226  ,  34222 , Count:  706
# Three Ports: 17140  ,  34226  ,  34230 , Count:  690
# Three Ports: 17140  ,  34226  ,  33966 , Count:  697
# Three Ports: 17140  ,  34226  ,  33974 , Count:  667
# Three Ports: 17140  ,  33970  ,  33972 , Count:  952
# Three Ports: 17140  ,  33970  ,  34222 , Count:  719
# Three Ports: 17140  ,  33970  ,  34230 , Count:  674
# Three Ports: 17140  ,  33970  ,  33966 , Count:  670
# Three Ports: 17140  ,  33970  ,  33974 , Count:  634
# Three Ports: 17140  ,  33972  ,  34222 , Count:  708
# Three Ports: 17140  ,  33972  ,  34230 , Count:  685
# Three Ports: 17140  ,  33972  ,  33966 , Count:  648
# Three Ports: 17140  ,  33972  ,  33974 , Count:  628
# Three Ports: 17140  ,  34222  ,  33966 , Count:  508
# Three Ports: 17140  ,  34230  ,  33966 , Count:  516
# Three Ports: 17128  ,  17138  ,  17130 , Count:  12507
# Three Ports: 17128  ,  17138  ,  17136 , Count:  12422
# Three Ports: 17128  ,  17138  ,  17142 , Count:  10378
# Three Ports: 17128  ,  17138  ,  17134 , Count:  10430
# Three Ports: 17128  ,  17138  ,  34218 , Count:  2474
# Three Ports: 17128  ,  17138  ,  34220 , Count:  2410
# Three Ports: 17128  ,  17138  ,  33968 , Count:  2412
# Three Ports: 17128  ,  17138  ,  34224 , Count:  2421
# Three Ports: 17128  ,  17138  ,  34228 , Count:  2415
# Three Ports: 17128  ,  17138  ,  33962 , Count:  2422
# Three Ports: 17128  ,  17138  ,  33960 , Count:  2420
# Three Ports: 17128  ,  17138  ,  33964 , Count:  2363
# Three Ports: 17128  ,  17138  ,  34216 , Count:  2369
# Three Ports: 17128  ,  17138  ,  34226 , Count:  2393
# Three Ports: 17128  ,  17138  ,  33970 , Count:  2359
# Three Ports: 17128  ,  17138  ,  33972 , Count:  2378
# Three Ports: 17128  ,  17138  ,  34222 , Count:  1535
# Three Ports: 17128  ,  17138  ,  34230 , Count:  1472
# Three Ports: 17128  ,  17138  ,  33966 , Count:  1488
# Three Ports: 17128  ,  17138  ,  33974 , Count:  1387
# Three Ports: 17128  ,  17130  ,  17136 , Count:  12523
# Three Ports: 17128  ,  17130  ,  17142 , Count:  10425
# Three Ports: 17128  ,  17130  ,  17134 , Count:  10492
# Three Ports: 17128  ,  17130  ,  34218 , Count:  2497
# Three Ports: 17128  ,  17130  ,  34220 , Count:  2423
# Three Ports: 17128  ,  17130  ,  33968 , Count:  2430
# Three Ports: 17128  ,  17130  ,  34224 , Count:  2444
# Three Ports: 17128  ,  17130  ,  34228 , Count:  2410
# Three Ports: 17128  ,  17130  ,  33962 , Count:  2448
# Three Ports: 17128  ,  17130  ,  33960 , Count:  2423
# Three Ports: 17128  ,  17130  ,  33964 , Count:  2351
# Three Ports: 17128  ,  17130  ,  34216 , Count:  2375
# Three Ports: 17128  ,  17130  ,  34226 , Count:  2365
# Three Ports: 17128  ,  17130  ,  33970 , Count:  2363
# Three Ports: 17128  ,  17130  ,  33972 , Count:  2372
# Three Ports: 17128  ,  17130  ,  34222 , Count:  1536
# Three Ports: 17128  ,  17130  ,  34230 , Count:  1472
# Three Ports: 17128  ,  17130  ,  33966 , Count:  1496
# Three Ports: 17128  ,  17130  ,  33974 , Count:  1397
# Three Ports: 17128  ,  17136  ,  17142 , Count:  10338
# Three Ports: 17128  ,  17136  ,  17134 , Count:  10418
# Three Ports: 17128  ,  17136  ,  34218 , Count:  2476
# Three Ports: 17128  ,  17136  ,  34220 , Count:  2421
# Three Ports: 17128  ,  17136  ,  33968 , Count:  2434
# Three Ports: 17128  ,  17136  ,  34224 , Count:  2439
# Three Ports: 17128  ,  17136  ,  34228 , Count:  2418
# Three Ports: 17128  ,  17136  ,  33962 , Count:  2441
# Three Ports: 17128  ,  17136  ,  33960 , Count:  2422
# Three Ports: 17128  ,  17136  ,  33964 , Count:  2364
# Three Ports: 17128  ,  17136  ,  34216 , Count:  2396
# Three Ports: 17128  ,  17136  ,  34226 , Count:  2373
# Three Ports: 17128  ,  17136  ,  33970 , Count:  2339
# Three Ports: 17128  ,  17136  ,  33972 , Count:  2372
# Three Ports: 17128  ,  17136  ,  34222 , Count:  1531
# Three Ports: 17128  ,  17136  ,  34230 , Count:  1479
# Three Ports: 17128  ,  17136  ,  33966 , Count:  1497
# Three Ports: 17128  ,  17136  ,  33974 , Count:  1385
# Three Ports: 17128  ,  17142  ,  17134 , Count:  8895
# Three Ports: 17128  ,  17142  ,  34218 , Count:  2294
# Three Ports: 17128  ,  17142  ,  34220 , Count:  2238
# Three Ports: 17128  ,  17142  ,  33968 , Count:  2264
# Three Ports: 17128  ,  17142  ,  34224 , Count:  2284
# Three Ports: 17128  ,  17142  ,  34228 , Count:  2251
# Three Ports: 17128  ,  17142  ,  33962 , Count:  2272
# Three Ports: 17128  ,  17142  ,  33960 , Count:  2260
# Three Ports: 17128  ,  17142  ,  33964 , Count:  2186
# Three Ports: 17128  ,  17142  ,  34216 , Count:  2217
# Three Ports: 17128  ,  17142  ,  34226 , Count:  2208
# Three Ports: 17128  ,  17142  ,  33970 , Count:  2195
# Three Ports: 17128  ,  17142  ,  33972 , Count:  2201
# Three Ports: 17128  ,  17142  ,  34222 , Count:  1454
# Three Ports: 17128  ,  17142  ,  34230 , Count:  1406
# Three Ports: 17128  ,  17142  ,  33966 , Count:  1419
# Three Ports: 17128  ,  17142  ,  33974 , Count:  1301
# Three Ports: 17128  ,  17134  ,  34218 , Count:  2318
# Three Ports: 17128  ,  17134  ,  34220 , Count:  2275
# Three Ports: 17128  ,  17134  ,  33968 , Count:  2259
# Three Ports: 17128  ,  17134  ,  34224 , Count:  2278
# Three Ports: 17128  ,  17134  ,  34228 , Count:  2253
# Three Ports: 17128  ,  17134  ,  33962 , Count:  2274
# Three Ports: 17128  ,  17134  ,  33960 , Count:  2254
# Three Ports: 17128  ,  17134  ,  33964 , Count:  2187
# Three Ports: 17128  ,  17134  ,  34216 , Count:  2227
# Three Ports: 17128  ,  17134  ,  34226 , Count:  2240
# Three Ports: 17128  ,  17134  ,  33970 , Count:  2182
# Three Ports: 17128  ,  17134  ,  33972 , Count:  2214
# Three Ports: 17128  ,  17134  ,  34222 , Count:  1456
# Three Ports: 17128  ,  17134  ,  34230 , Count:  1404
# Three Ports: 17128  ,  17134  ,  33966 , Count:  1417
# Three Ports: 17128  ,  17134  ,  33974 , Count:  1318
# Three Ports: 17128  ,  34218  ,  34220 , Count:  1006
# Three Ports: 17128  ,  34218  ,  33968 , Count:  1029
# Three Ports: 17128  ,  34218  ,  34224 , Count:  1073
# Three Ports: 17128  ,  34218  ,  34228 , Count:  981
# Three Ports: 17128  ,  34218  ,  33962 , Count:  1023
# Three Ports: 17128  ,  34218  ,  33960 , Count:  1004
# Three Ports: 17128  ,  34218  ,  33964 , Count:  977
# Three Ports: 17128  ,  34218  ,  34216 , Count:  994
# Three Ports: 17128  ,  34218  ,  34226 , Count:  1014
# Three Ports: 17128  ,  34218  ,  33970 , Count:  992
# Three Ports: 17128  ,  34218  ,  33972 , Count:  973
# Three Ports: 17128  ,  34218  ,  34222 , Count:  714
# Three Ports: 17128  ,  34218  ,  34230 , Count:  689
# Three Ports: 17128  ,  34218  ,  33966 , Count:  698
# Three Ports: 17128  ,  34218  ,  33974 , Count:  658
# Three Ports: 17128  ,  34220  ,  33968 , Count:  1018
# Three Ports: 17128  ,  34220  ,  34224 , Count:  1034
# Three Ports: 17128  ,  34220  ,  34228 , Count:  988
# Three Ports: 17128  ,  34220  ,  33962 , Count:  1004
# Three Ports: 17128  ,  34220  ,  33960 , Count:  991
# Three Ports: 17128  ,  34220  ,  33964 , Count:  1001
# Three Ports: 17128  ,  34220  ,  34216 , Count:  967
# Three Ports: 17128  ,  34220  ,  34226 , Count:  996
# Three Ports: 17128  ,  34220  ,  33970 , Count:  967
# Three Ports: 17128  ,  34220  ,  33972 , Count:  971
# Three Ports: 17128  ,  34220  ,  34222 , Count:  740
# Three Ports: 17128  ,  34220  ,  34230 , Count:  682
# Three Ports: 17128  ,  34220  ,  33966 , Count:  694
# Three Ports: 17128  ,  34220  ,  33974 , Count:  651
# Three Ports: 17128  ,  33968  ,  34224 , Count:  1028
# Three Ports: 17128  ,  33968  ,  34228 , Count:  988
# Three Ports: 17128  ,  33968  ,  33962 , Count:  1004
# Three Ports: 17128  ,  33968  ,  33960 , Count:  1020
# Three Ports: 17128  ,  33968  ,  33964 , Count:  989
# Three Ports: 17128  ,  33968  ,  34216 , Count:  1000
# Three Ports: 17128  ,  33968  ,  34226 , Count:  1009
# Three Ports: 17128  ,  33968  ,  33970 , Count:  988
# Three Ports: 17128  ,  33968  ,  33972 , Count:  977
# Three Ports: 17128  ,  33968  ,  34222 , Count:  718
# Three Ports: 17128  ,  33968  ,  34230 , Count:  691
# Three Ports: 17128  ,  33968  ,  33966 , Count:  685
# Three Ports: 17128  ,  33968  ,  33974 , Count:  651
# Three Ports: 17128  ,  34224  ,  34228 , Count:  999
# Three Ports: 17128  ,  34224  ,  33962 , Count:  1014
# Three Ports: 17128  ,  34224  ,  33960 , Count:  1012
# Three Ports: 17128  ,  34224  ,  33964 , Count:  990
# Three Ports: 17128  ,  34224  ,  34216 , Count:  1011
# Three Ports: 17128  ,  34224  ,  34226 , Count:  1014
# Three Ports: 17128  ,  34224  ,  33970 , Count:  996
# Three Ports: 17128  ,  34224  ,  33972 , Count:  1002
# Three Ports: 17128  ,  34224  ,  34222 , Count:  719
# Three Ports: 17128  ,  34224  ,  34230 , Count:  683
# Three Ports: 17128  ,  34224  ,  33966 , Count:  707
# Three Ports: 17128  ,  34224  ,  33974 , Count:  647
# Three Ports: 17128  ,  34228  ,  33962 , Count:  1012
# Three Ports: 17128  ,  34228  ,  33960 , Count:  970
# Three Ports: 17128  ,  34228  ,  33964 , Count:  972
# Three Ports: 17128  ,  34228  ,  34216 , Count:  988
# Three Ports: 17128  ,  34228  ,  34226 , Count:  1001
# Three Ports: 17128  ,  34228  ,  33970 , Count:  969
# Three Ports: 17128  ,  34228  ,  33972 , Count:  941
# Three Ports: 17128  ,  34228  ,  34222 , Count:  704
# Three Ports: 17128  ,  34228  ,  34230 , Count:  688
# Three Ports: 17128  ,  34228  ,  33966 , Count:  672
# Three Ports: 17128  ,  34228  ,  33974 , Count:  633
# Three Ports: 17128  ,  33962  ,  33960 , Count:  999
# Three Ports: 17128  ,  33962  ,  33964 , Count:  992
# Three Ports: 17128  ,  33962  ,  34216 , Count:  991
# Three Ports: 17128  ,  33962  ,  34226 , Count:  1025
# Three Ports: 17128  ,  33962  ,  33970 , Count:  1003
# Three Ports: 17128  ,  33962  ,  33972 , Count:  975
# Three Ports: 17128  ,  33962  ,  34222 , Count:  711
# Three Ports: 17128  ,  33962  ,  34230 , Count:  707
# Three Ports: 17128  ,  33962  ,  33966 , Count:  723
# Three Ports: 17128  ,  33962  ,  33974 , Count:  663
# Three Ports: 17128  ,  33960  ,  33964 , Count:  996
# Three Ports: 17128  ,  33960  ,  34216 , Count:  985
# Three Ports: 17128  ,  33960  ,  34226 , Count:  1023
# Three Ports: 17128  ,  33960  ,  33970 , Count:  966
# Three Ports: 17128  ,  33960  ,  33972 , Count:  980
# Three Ports: 17128  ,  33960  ,  34222 , Count:  721
# Three Ports: 17128  ,  33960  ,  34230 , Count:  683
# Three Ports: 17128  ,  33960  ,  33966 , Count:  695
# Three Ports: 17128  ,  33960  ,  33974 , Count:  658
# Three Ports: 17128  ,  33964  ,  34216 , Count:  958
# Three Ports: 17128  ,  33964  ,  34226 , Count:  988
# Three Ports: 17128  ,  33964  ,  33970 , Count:  980
# Three Ports: 17128  ,  33964  ,  33972 , Count:  950
# Three Ports: 17128  ,  33964  ,  34222 , Count:  684
# Three Ports: 17128  ,  33964  ,  34230 , Count:  678
# Three Ports: 17128  ,  33964  ,  33966 , Count:  667
# Three Ports: 17128  ,  33964  ,  33974 , Count:  644
# Three Ports: 17128  ,  34216  ,  34226 , Count:  1005
# Three Ports: 17128  ,  34216  ,  33970 , Count:  986
# Three Ports: 17128  ,  34216  ,  33972 , Count:  980
# Three Ports: 17128  ,  34216  ,  34222 , Count:  692
# Three Ports: 17128  ,  34216  ,  34230 , Count:  693
# Three Ports: 17128  ,  34216  ,  33966 , Count:  670
# Three Ports: 17128  ,  34216  ,  33974 , Count:  653
# Three Ports: 17128  ,  34226  ,  33970 , Count:  987
# Three Ports: 17128  ,  34226  ,  33972 , Count:  1008
# Three Ports: 17128  ,  34226  ,  34222 , Count:  704
# Three Ports: 17128  ,  34226  ,  34230 , Count:  692
# Three Ports: 17128  ,  34226  ,  33966 , Count:  698
# Three Ports: 17128  ,  34226  ,  33974 , Count:  671
# Three Ports: 17128  ,  33970  ,  33972 , Count:  955
# Three Ports: 17128  ,  33970  ,  34222 , Count:  719
# Three Ports: 17128  ,  33970  ,  34230 , Count:  671
# Three Ports: 17128  ,  33970  ,  33966 , Count:  674
# Three Ports: 17128  ,  33970  ,  33974 , Count:  634
# Three Ports: 17128  ,  33972  ,  34222 , Count:  711
# Three Ports: 17128  ,  33972  ,  34230 , Count:  684
# Three Ports: 17128  ,  33972  ,  33966 , Count:  649
# Three Ports: 17128  ,  33972  ,  33974 , Count:  629
# Three Ports: 17128  ,  34222  ,  33966 , Count:  509
# Three Ports: 17128  ,  34230  ,  33966 , Count:  518
# Three Ports: 17138  ,  17130  ,  17136 , Count:  12439
# Three Ports: 17138  ,  17130  ,  17142 , Count:  10357
# Three Ports: 17138  ,  17130  ,  17134 , Count:  10438
# Three Ports: 17138  ,  17130  ,  34218 , Count:  2480
# Three Ports: 17138  ,  17130  ,  34220 , Count:  2404
# Three Ports: 17138  ,  17130  ,  33968 , Count:  2420
# Three Ports: 17138  ,  17130  ,  34224 , Count:  2431
# Three Ports: 17138  ,  17130  ,  34228 , Count:  2389
# Three Ports: 17138  ,  17130  ,  33962 , Count:  2428
# Three Ports: 17138  ,  17130  ,  33960 , Count:  2422
# Three Ports: 17138  ,  17130  ,  33964 , Count:  2347
# Three Ports: 17138  ,  17130  ,  34216 , Count:  2357
# Three Ports: 17138  ,  17130  ,  34226 , Count:  2385
# Three Ports: 17138  ,  17130  ,  33970 , Count:  2381
# Three Ports: 17138  ,  17130  ,  33972 , Count:  2371
# Three Ports: 17138  ,  17130  ,  34222 , Count:  1508
# Three Ports: 17138  ,  17130  ,  34230 , Count:  1482
# Three Ports: 17138  ,  17130  ,  33966 , Count:  1487
# Three Ports: 17138  ,  17130  ,  33974 , Count:  1392
# Three Ports: 17138  ,  17136  ,  17142 , Count:  10277
# Three Ports: 17138  ,  17136  ,  17134 , Count:  10378
# Three Ports: 17138  ,  17136  ,  34218 , Count:  2464
# Three Ports: 17138  ,  17136  ,  34220 , Count:  2414
# Three Ports: 17138  ,  17136  ,  33968 , Count:  2408
# Three Ports: 17138  ,  17136  ,  34224 , Count:  2423
# Three Ports: 17138  ,  17136  ,  34228 , Count:  2398
# Three Ports: 17138  ,  17136  ,  33962 , Count:  2410
# Three Ports: 17138  ,  17136  ,  33960 , Count:  2422
# Three Ports: 17138  ,  17136  ,  33964 , Count:  2356
# Three Ports: 17138  ,  17136  ,  34216 , Count:  2377
# Three Ports: 17138  ,  17136  ,  34226 , Count:  2396
# Three Ports: 17138  ,  17136  ,  33970 , Count:  2349
# Three Ports: 17138  ,  17136  ,  33972 , Count:  2376
# Three Ports: 17138  ,  17136  ,  34222 , Count:  1514
# Three Ports: 17138  ,  17136  ,  34230 , Count:  1475
# Three Ports: 17138  ,  17136  ,  33966 , Count:  1477
# Three Ports: 17138  ,  17136  ,  33974 , Count:  1391
# Three Ports: 17138  ,  17142  ,  17134 , Count:  8873
# Three Ports: 17138  ,  17142  ,  34218 , Count:  2287
# Three Ports: 17138  ,  17142  ,  34220 , Count:  2237
# Three Ports: 17138  ,  17142  ,  33968 , Count:  2245
# Three Ports: 17138  ,  17142  ,  34224 , Count:  2288
# Three Ports: 17138  ,  17142  ,  34228 , Count:  2250
# Three Ports: 17138  ,  17142  ,  33962 , Count:  2260
# Three Ports: 17138  ,  17142  ,  33960 , Count:  2252
# Three Ports: 17138  ,  17142  ,  33964 , Count:  2187
# Three Ports: 17138  ,  17142  ,  34216 , Count:  2208
# Three Ports: 17138  ,  17142  ,  34226 , Count:  2229
# Three Ports: 17138  ,  17142  ,  33970 , Count:  2215
# Three Ports: 17138  ,  17142  ,  33972 , Count:  2212
# Three Ports: 17138  ,  17142  ,  34222 , Count:  1444
# Three Ports: 17138  ,  17142  ,  34230 , Count:  1393
# Three Ports: 17138  ,  17142  ,  33966 , Count:  1407
# Three Ports: 17138  ,  17142  ,  33974 , Count:  1310
# Three Ports: 17138  ,  17134  ,  34218 , Count:  2310
# Three Ports: 17138  ,  17134  ,  34220 , Count:  2256
# Three Ports: 17138  ,  17134  ,  33968 , Count:  2252
# Three Ports: 17138  ,  17134  ,  34224 , Count:  2277
# Three Ports: 17138  ,  17134  ,  34228 , Count:  2245
# Three Ports: 17138  ,  17134  ,  33962 , Count:  2248
# Three Ports: 17138  ,  17134  ,  33960 , Count:  2256
# Three Ports: 17138  ,  17134  ,  33964 , Count:  2180
# Three Ports: 17138  ,  17134  ,  34216 , Count:  2233
# Three Ports: 17138  ,  17134  ,  34226 , Count:  2261
# Three Ports: 17138  ,  17134  ,  33970 , Count:  2185
# Three Ports: 17138  ,  17134  ,  33972 , Count:  2215
# Three Ports: 17138  ,  17134  ,  34222 , Count:  1453
# Three Ports: 17138  ,  17134  ,  34230 , Count:  1403
# Three Ports: 17138  ,  17134  ,  33966 , Count:  1412
# Three Ports: 17138  ,  17134  ,  33974 , Count:  1324
# Three Ports: 17138  ,  34218  ,  34220 , Count:  1005
# Three Ports: 17138  ,  34218  ,  33968 , Count:  1026
# Three Ports: 17138  ,  34218  ,  34224 , Count:  1074
# Three Ports: 17138  ,  34218  ,  34228 , Count:  981
# Three Ports: 17138  ,  34218  ,  33962 , Count:  1028
# Three Ports: 17138  ,  34218  ,  33960 , Count:  1009
# Three Ports: 17138  ,  34218  ,  33964 , Count:  978
# Three Ports: 17138  ,  34218  ,  34216 , Count:  990
# Three Ports: 17138  ,  34218  ,  34226 , Count:  1017
# Three Ports: 17138  ,  34218  ,  33970 , Count:  994
# Three Ports: 17138  ,  34218  ,  33972 , Count:  973
# Three Ports: 17138  ,  34218  ,  34222 , Count:  716
# Three Ports: 17138  ,  34218  ,  34230 , Count:  691
# Three Ports: 17138  ,  34218  ,  33966 , Count:  703
# Three Ports: 17138  ,  34218  ,  33974 , Count:  659
# Three Ports: 17138  ,  34220  ,  33968 , Count:  1016
# Three Ports: 17138  ,  34220  ,  34224 , Count:  1033
# Three Ports: 17138  ,  34220  ,  34228 , Count:  988
# Three Ports: 17138  ,  34220  ,  33962 , Count:  1001
# Three Ports: 17138  ,  34220  ,  33960 , Count:  989
# Three Ports: 17138  ,  34220  ,  33964 , Count:  1000
# Three Ports: 17138  ,  34220  ,  34216 , Count:  971
# Three Ports: 17138  ,  34220  ,  34226 , Count:  1002
# Three Ports: 17138  ,  34220  ,  33970 , Count:  969
# Three Ports: 17138  ,  34220  ,  33972 , Count:  977
# Three Ports: 17138  ,  34220  ,  34222 , Count:  741
# Three Ports: 17138  ,  34220  ,  34230 , Count:  685
# Three Ports: 17138  ,  34220  ,  33966 , Count:  698
# Three Ports: 17138  ,  34220  ,  33974 , Count:  654
# Three Ports: 17138  ,  33968  ,  34224 , Count:  1029
# Three Ports: 17138  ,  33968  ,  34228 , Count:  987
# Three Ports: 17138  ,  33968  ,  33962 , Count:  1001
# Three Ports: 17138  ,  33968  ,  33960 , Count:  1025
# Three Ports: 17138  ,  33968  ,  33964 , Count:  995
# Three Ports: 17138  ,  33968  ,  34216 , Count:  1001
# Three Ports: 17138  ,  33968  ,  34226 , Count:  1011
# Three Ports: 17138  ,  33968  ,  33970 , Count:  996
# Three Ports: 17138  ,  33968  ,  33972 , Count:  978
# Three Ports: 17138  ,  33968  ,  34222 , Count:  722
# Three Ports: 17138  ,  33968  ,  34230 , Count:  694
# Three Ports: 17138  ,  33968  ,  33966 , Count:  687
# Three Ports: 17138  ,  33968  ,  33974 , Count:  657
# Three Ports: 17138  ,  34224  ,  34228 , Count:  1002
# Three Ports: 17138  ,  34224  ,  33962 , Count:  1015
# Three Ports: 17138  ,  34224  ,  33960 , Count:  1018
# Three Ports: 17138  ,  34224  ,  33964 , Count:  987
# Three Ports: 17138  ,  34224  ,  34216 , Count:  1011
# Three Ports: 17138  ,  34224  ,  34226 , Count:  1020
# Three Ports: 17138  ,  34224  ,  33970 , Count:  995
# Three Ports: 17138  ,  34224  ,  33972 , Count:  1005
# Three Ports: 17138  ,  34224  ,  34222 , Count:  725
# Three Ports: 17138  ,  34224  ,  34230 , Count:  688
# Three Ports: 17138  ,  34224  ,  33966 , Count:  711
# Three Ports: 17138  ,  34224  ,  33974 , Count:  652
# Three Ports: 17138  ,  34228  ,  33962 , Count:  1007
# Three Ports: 17138  ,  34228  ,  33960 , Count:  967
# Three Ports: 17138  ,  34228  ,  33964 , Count:  965
# Three Ports: 17138  ,  34228  ,  34216 , Count:  982
# Three Ports: 17138  ,  34228  ,  34226 , Count:  1002
# Three Ports: 17138  ,  34228  ,  33970 , Count:  963
# Three Ports: 17138  ,  34228  ,  33972 , Count:  941
# Three Ports: 17138  ,  34228  ,  34222 , Count:  704
# Three Ports: 17138  ,  34228  ,  34230 , Count:  689
# Three Ports: 17138  ,  34228  ,  33966 , Count:  666
# Three Ports: 17138  ,  34228  ,  33974 , Count:  637
# Three Ports: 17138  ,  33962  ,  33960 , Count:  1000
# Three Ports: 17138  ,  33962  ,  33964 , Count:  989
# Three Ports: 17138  ,  33962  ,  34216 , Count:  988
# Three Ports: 17138  ,  33962  ,  34226 , Count:  1032
# Three Ports: 17138  ,  33962  ,  33970 , Count:  1005
# Three Ports: 17138  ,  33962  ,  33972 , Count:  977
# Three Ports: 17138  ,  33962  ,  34222 , Count:  714
# Three Ports: 17138  ,  33962  ,  34230 , Count:  708
# Three Ports: 17138  ,  33962  ,  33966 , Count:  723
# Three Ports: 17138  ,  33962  ,  33974 , Count:  664
# Three Ports: 17138  ,  33960  ,  33964 , Count:  988
# Three Ports: 17138  ,  33960  ,  34216 , Count:  987
# Three Ports: 17138  ,  33960  ,  34226 , Count:  1021
# Three Ports: 17138  ,  33960  ,  33970 , Count:  971
# Three Ports: 17138  ,  33960  ,  33972 , Count:  988
# Three Ports: 17138  ,  33960  ,  34222 , Count:  723
# Three Ports: 17138  ,  33960  ,  34230 , Count:  687
# Three Ports: 17138  ,  33960  ,  33966 , Count:  696
# Three Ports: 17138  ,  33960  ,  33974 , Count:  661
# Three Ports: 17138  ,  33964  ,  34216 , Count:  953
# Three Ports: 17138  ,  33964  ,  34226 , Count:  991
# Three Ports: 17138  ,  33964  ,  33970 , Count:  985
# Three Ports: 17138  ,  33964  ,  33972 , Count:  950
# Three Ports: 17138  ,  33964  ,  34222 , Count:  684
# Three Ports: 17138  ,  33964  ,  34230 , Count:  682
# Three Ports: 17138  ,  33964  ,  33966 , Count:  665
# Three Ports: 17138  ,  33964  ,  33974 , Count:  647
# Three Ports: 17138  ,  34216  ,  34226 , Count:  1006
# Three Ports: 17138  ,  34216  ,  33970 , Count:  983
# Three Ports: 17138  ,  34216  ,  33972 , Count:  978
# Three Ports: 17138  ,  34216  ,  34222 , Count:  696
# Three Ports: 17138  ,  34216  ,  34230 , Count:  693
# Three Ports: 17138  ,  34216  ,  33966 , Count:  675
# Three Ports: 17138  ,  34216  ,  33974 , Count:  654
# Three Ports: 17138  ,  34226  ,  33970 , Count:  987
# Three Ports: 17138  ,  34226  ,  33972 , Count:  1017
# Three Ports: 17138  ,  34226  ,  34222 , Count:  705
# Three Ports: 17138  ,  34226  ,  34230 , Count:  699
# Three Ports: 17138  ,  34226  ,  33966 , Count:  700
# Three Ports: 17138  ,  34226  ,  33974 , Count:  672
# Three Ports: 17138  ,  33970  ,  33972 , Count:  957
# Three Ports: 17138  ,  33970  ,  34222 , Count:  720
# Three Ports: 17138  ,  33970  ,  34230 , Count:  676
# Three Ports: 17138  ,  33970  ,  33966 , Count:  675
# Three Ports: 17138  ,  33970  ,  33974 , Count:  636
# Three Ports: 17138  ,  33972  ,  34222 , Count:  711
# Three Ports: 17138  ,  33972  ,  34230 , Count:  684
# Three Ports: 17138  ,  33972  ,  33966 , Count:  650
# Three Ports: 17138  ,  33972  ,  33974 , Count:  630
# Three Ports: 17138  ,  34222  ,  33966 , Count:  511
# Three Ports: 17138  ,  34230  ,  33966 , Count:  522
# Three Ports: 17130  ,  17136  ,  17142 , Count:  10314
# Three Ports: 17130  ,  17136  ,  17134 , Count:  10448
# Three Ports: 17130  ,  17136  ,  34218 , Count:  2469
# Three Ports: 17130  ,  17136  ,  34220 , Count:  2406
# Three Ports: 17130  ,  17136  ,  33968 , Count:  2420
# Three Ports: 17130  ,  17136  ,  34224 , Count:  2441
# Three Ports: 17130  ,  17136  ,  34228 , Count:  2377
# Three Ports: 17130  ,  17136  ,  33962 , Count:  2427
# Three Ports: 17130  ,  17136  ,  33960 , Count:  2419
# Three Ports: 17130  ,  17136  ,  33964 , Count:  2362
# Three Ports: 17130  ,  17136  ,  34216 , Count:  2374
# Three Ports: 17130  ,  17136  ,  34226 , Count:  2377
# Three Ports: 17130  ,  17136  ,  33970 , Count:  2357
# Three Ports: 17130  ,  17136  ,  33972 , Count:  2354
# Three Ports: 17130  ,  17136  ,  34222 , Count:  1516
# Three Ports: 17130  ,  17136  ,  34230 , Count:  1483
# Three Ports: 17130  ,  17136  ,  33966 , Count:  1483
# Three Ports: 17130  ,  17136  ,  33974 , Count:  1386
# Three Ports: 17130  ,  17142  ,  17134 , Count:  8869
# Three Ports: 17130  ,  17142  ,  34218 , Count:  2288
# Three Ports: 17130  ,  17142  ,  34220 , Count:  2243
# Three Ports: 17130  ,  17142  ,  33968 , Count:  2255
# Three Ports: 17130  ,  17142  ,  34224 , Count:  2290
# Three Ports: 17130  ,  17142  ,  34228 , Count:  2233
# Three Ports: 17130  ,  17142  ,  33962 , Count:  2280
# Three Ports: 17130  ,  17142  ,  33960 , Count:  2243
# ...
# Three Ports: 2323  ,  1023  ,  8443 , Count:  3383
# Three Ports: 2323  ,  1023  ,  49152 , Count:  3355
# Three Ports: 2323  ,  1023  ,  7574 , Count:  3289
# Three Ports: 2323  ,  1023  ,  37215 , Count:  3357
# Three Ports: 2323  ,  52869  ,  8443 , Count:  3262
# Three Ports: 2323  ,  52869  ,  49152 , Count:  3242
# Three Ports: 2323  ,  52869  ,  7574 , Count:  3173
# Three Ports: 2323  ,  52869  ,  37215 , Count:  3240
# Three Ports: 2323  ,  8443  ,  49152 , Count:  3241
# Three Ports: 2323  ,  8443  ,  7574 , Count:  3193
# Three Ports: 2323  ,  8443  ,  37215 , Count:  3257
# Three Ports: 2323  ,  49152  ,  7574 , Count:  3172
# Three Ports: 2323  ,  49152  ,  37215 , Count:  3238
# Three Ports: 2323  ,  7574  ,  37215 , Count:  3178
# Three Ports: 5555  ,  81  ,  1023 , Count:  3074
# Three Ports: 5555  ,  81  ,  52869 , Count:  3100
# Three Ports: 5555  ,  81  ,  8443 , Count:  3135
# Three Ports: 5555  ,  81  ,  49152 , Count:  3092
# Three Ports: 5555  ,  81  ,  7574 , Count:  3033
# Three Ports: 5555  ,  81  ,  37215 , Count:  3057
# Three Ports: 5555  ,  1023  ,  52869 , Count:  3059
# Three Ports: 5555  ,  1023  ,  8443 , Count:  3098
# Three Ports: 5555  ,  1023  ,  49152 , Count:  3056
# Three Ports: 5555  ,  1023  ,  7574 , Count:  3006
# Three Ports: 5555  ,  1023  ,  37215 , Count:  2997
# Three Ports: 5555  ,  52869  ,  8443 , Count:  3111
# Three Ports: 5555  ,  52869  ,  49152 , Count:  3091
# Three Ports: 5555  ,  52869  ,  7574 , Count:  3027
# Three Ports: 5555  ,  52869  ,  37215 , Count:  3031
# Three Ports: 5555  ,  8443  ,  49152 , Count:  3108
# Three Ports: 5555  ,  8443  ,  7574 , Count:  3052
# Three Ports: 5555  ,  8443  ,  37215 , Count:  3059
# Three Ports: 5555  ,  49152  ,  7574 , Count:  3036
# Three Ports: 5555  ,  49152  ,  37215 , Count:  3038
# Three Ports: 5555  ,  7574  ,  37215 , Count:  2976
# Three Ports: 81  ,  1023  ,  52869 , Count:  3105
# Three Ports: 81  ,  1023  ,  8443 , Count:  3125
# Three Ports: 81  ,  1023  ,  49152 , Count:  3097
# Three Ports: 81  ,  1023  ,  7574 , Count:  3038
# Three Ports: 81  ,  1023  ,  37215 , Count:  3053
# Three Ports: 81  ,  52869  ,  8443 , Count:  3155
# Three Ports: 81  ,  52869  ,  49152 , Count:  3124
# Three Ports: 81  ,  52869  ,  7574 , Count:  3075
# Three Ports: 81  ,  52869  ,  37215 , Count:  3095
# Three Ports: 81  ,  8443  ,  49152 , Count:  3140
# Three Ports: 81  ,  8443  ,  7574 , Count:  3099
# Three Ports: 81  ,  8443  ,  37215 , Count:  3111
# Three Ports: 81  ,  49152  ,  7574 , Count:  3060
# Three Ports: 81  ,  49152  ,  37215 , Count:  3072
# Three Ports: 81  ,  7574  ,  37215 , Count:  3019
# Three Ports: 1023  ,  52869  ,  8443 , Count:  3124
# Three Ports: 1023  ,  52869  ,  49152 , Count:  3100
# Three Ports: 1023  ,  52869  ,  7574 , Count:  3039
# Three Ports: 1023  ,  52869  ,  37215 , Count:  3034
# Three Ports: 1023  ,  8443  ,  49152 , Count:  3103
# Three Ports: 1023  ,  8443  ,  7574 , Count:  3060
# Three Ports: 1023  ,  8443  ,  37215 , Count:  3045
# Three Ports: 1023  ,  49152  ,  7574 , Count:  3042
# Three Ports: 1023  ,  49152  ,  37215 , Count:  3043
# Three Ports: 1023  ,  7574  ,  37215 , Count:  2973
# Three Ports: 52869  ,  8443  ,  49152 , Count:  3127
# Three Ports: 52869  ,  8443  ,  7574 , Count:  3086
# Three Ports: 52869  ,  8443  ,  37215 , Count:  3083
# Three Ports: 52869  ,  49152  ,  7574 , Count:  3073
# Three Ports: 52869  ,  49152  ,  37215 , Count:  3076
# Three Ports: 52869  ,  7574  ,  37215 , Count:  3001
# Three Ports: 8443  ,  49152  ,  7574 , Count:  3075
# Three Ports: 8443  ,  49152  ,  37215 , Count:  3080
# Three Ports: 8443  ,  7574  ,  37215 , Count:  3017
# Three Ports: 49152  ,  7574  ,  37215 , Count:  3001
# Three Ports: 34218  ,  34220  ,  33968 , Count:  642
# Three Ports: 34218  ,  34220  ,  34224 , Count:  665
# Three Ports: 34218  ,  34220  ,  34228 , Count:  613
# Three Ports: 34218  ,  34220  ,  33962 , Count:  651
# Three Ports: 34218  ,  34220  ,  33960 , Count:  641
# Three Ports: 34218  ,  34220  ,  33964 , Count:  621
# Three Ports: 34218  ,  34220  ,  34216 , Count:  628
# Three Ports: 34218  ,  34220  ,  34226 , Count:  635
# Three Ports: 34218  ,  34220  ,  33970 , Count:  633
# Three Ports: 34218  ,  34220  ,  33972 , Count:  612
# Three Ports: 34218  ,  34220  ,  34222 , Count:  511
# Three Ports: 34218  ,  33968  ,  34224 , Count:  682
# Three Ports: 34218  ,  33968  ,  34228 , Count:  653
# Three Ports: 34218  ,  33968  ,  33962 , Count:  667
# Three Ports: 34218  ,  33968  ,  33960 , Count:  669
# Three Ports: 34218  ,  33968  ,  33964 , Count:  622
# Three Ports: 34218  ,  33968  ,  34216 , Count:  641
# Three Ports: 34218  ,  33968  ,  34226 , Count:  655
# Three Ports: 34218  ,  33968  ,  33970 , Count:  639
# Three Ports: 34218  ,  33968  ,  33972 , Count:  641
# Three Ports: 34218  ,  34224  ,  34228 , Count:  652
# Three Ports: 34218  ,  34224  ,  33962 , Count:  674
# Three Ports: 34218  ,  34224  ,  33960 , Count:  677
# Three Ports: 34218  ,  34224  ,  33964 , Count:  643
# Three Ports: 34218  ,  34224  ,  34216 , Count:  659
# Three Ports: 34218  ,  34224  ,  34226 , Count:  648
# Three Ports: 34218  ,  34224  ,  33970 , Count:  653
# Three Ports: 34218  ,  34224  ,  33972 , Count:  642
# Three Ports: 34218  ,  34224  ,  34222 , Count:  503
# Three Ports: 34218  ,  34228  ,  33962 , Count:  651
# Three Ports: 34218  ,  34228  ,  33960 , Count:  624
# Three Ports: 34218  ,  34228  ,  33964 , Count:  615
# Three Ports: 34218  ,  34228  ,  34216 , Count:  624
# Three Ports: 34218  ,  34228  ,  34226 , Count:  620
# Three Ports: 34218  ,  34228  ,  33970 , Count:  607
# Three Ports: 34218  ,  34228  ,  33972 , Count:  597
# Three Ports: 34218  ,  33962  ,  33960 , Count:  654
# Three Ports: 34218  ,  33962  ,  33964 , Count:  644
# Three Ports: 34218  ,  33962  ,  34216 , Count:  651
# Three Ports: 34218  ,  33962  ,  34226 , Count:  656
# Three Ports: 34218  ,  33962  ,  33970 , Count:  651
# Three Ports: 34218  ,  33962  ,  33972 , Count:  639
# Three Ports: 34218  ,  33962  ,  34222 , Count:  501
# Three Ports: 34218  ,  33960  ,  33964 , Count:  634
# Three Ports: 34218  ,  33960  ,  34216 , Count:  637
# Three Ports: 34218  ,  33960  ,  34226 , Count:  655
# Three Ports: 34218  ,  33960  ,  33970 , Count:  631
# Three Ports: 34218  ,  33960  ,  33972 , Count:  632
# Three Ports: 34218  ,  33964  ,  34216 , Count:  616
# Three Ports: 34218  ,  33964  ,  34226 , Count:  630
# Three Ports: 34218  ,  33964  ,  33970 , Count:  635
# Three Ports: 34218  ,  33964  ,  33972 , Count:  599
# Three Ports: 34218  ,  34216  ,  34226 , Count:  625
# Three Ports: 34218  ,  34216  ,  33970 , Count:  619
# Three Ports: 34218  ,  34216  ,  33972 , Count:  623
# Three Ports: 34218  ,  34226  ,  33970 , Count:  627
# Three Ports: 34218  ,  34226  ,  33972 , Count:  630
# Three Ports: 34218  ,  33970  ,  33972 , Count:  617
# Three Ports: 34220  ,  33968  ,  34224 , Count:  680
# Three Ports: 34220  ,  33968  ,  34228 , Count:  633
# Three Ports: 34220  ,  33968  ,  33962 , Count:  658
# Three Ports: 34220  ,  33968  ,  33960 , Count:  653
# Three Ports: 34220  ,  33968  ,  33964 , Count:  649
# Three Ports: 34220  ,  33968  ,  34216 , Count:  654
# Three Ports: 34220  ,  33968  ,  34226 , Count:  645
# Three Ports: 34220  ,  33968  ,  33970 , Count:  637
# Three Ports: 34220  ,  33968  ,  33972 , Count:  630
# Three Ports: 34220  ,  34224  ,  34228 , Count:  644
# Three Ports: 34220  ,  34224  ,  33962 , Count:  658
# Three Ports: 34220  ,  34224  ,  33960 , Count:  647
# Three Ports: 34220  ,  34224  ,  33964 , Count:  653
# Three Ports: 34220  ,  34224  ,  34216 , Count:  643
# Three Ports: 34220  ,  34224  ,  34226 , Count:  654
# Three Ports: 34220  ,  34224  ,  33970 , Count:  654
# Three Ports: 34220  ,  34224  ,  33972 , Count:  637
# Three Ports: 34220  ,  34224  ,  34222 , Count:  514
# Three Ports: 34220  ,  34228  ,  33962 , Count:  648
# Three Ports: 34220  ,  34228  ,  33960 , Count:  624
# Three Ports: 34220  ,  34228  ,  33964 , Count:  628
# Three Ports: 34220  ,  34228  ,  34216 , Count:  619
# Three Ports: 34220  ,  34228  ,  34226 , Count:  618
# Three Ports: 34220  ,  34228  ,  33970 , Count:  605
# Three Ports: 34220  ,  34228  ,  33972 , Count:  590
# Three Ports: 34220  ,  33962  ,  33960 , Count:  643
# Three Ports: 34220  ,  33962  ,  33964 , Count:  641
# Three Ports: 34220  ,  33962  ,  34216 , Count:  628
# Three Ports: 34220  ,  33962  ,  34226 , Count:  639
# Three Ports: 34220  ,  33962  ,  33970 , Count:  640
# Three Ports: 34220  ,  33962  ,  33972 , Count:  622
# Three Ports: 34220  ,  33962  ,  34222 , Count:  511
# Three Ports: 34220  ,  33960  ,  33964 , Count:  650
# Three Ports: 34220  ,  33960  ,  34216 , Count:  620
# Three Ports: 34220  ,  33960  ,  34226 , Count:  652
# Three Ports: 34220  ,  33960  ,  33970 , Count:  623
# Three Ports: 34220  ,  33960  ,  33972 , Count:  611
# Three Ports: 34220  ,  33960  ,  34222 , Count:  510
# Three Ports: 34220  ,  33964  ,  34216 , Count:  622
# Three Ports: 34220  ,  33964  ,  34226 , Count:  631
# Three Ports: 34220  ,  33964  ,  33970 , Count:  633
# Three Ports: 34220  ,  33964  ,  33972 , Count:  627
# Three Ports: 34220  ,  34216  ,  34226 , Count:  625
# Three Ports: 34220  ,  34216  ,  33970 , Count:  613
# Three Ports: 34220  ,  34216  ,  33972 , Count:  622
# Three Ports: 34220  ,  34226  ,  33970 , Count:  619
# Three Ports: 34220  ,  34226  ,  33972 , Count:  628
# Three Ports: 34220  ,  33970  ,  33972 , Count:  614
# Three Ports: 34220  ,  33970  ,  34222 , Count:  501
# Three Ports: 33968  ,  34224  ,  34228 , Count:  642
# Three Ports: 33968  ,  34224  ,  33962 , Count:  654
# Three Ports: 33968  ,  34224  ,  33960 , Count:  672
# Three Ports: 33968  ,  34224  ,  33964 , Count:  631
# Three Ports: 33968  ,  34224  ,  34216 , Count:  661
# Three Ports: 33968  ,  34224  ,  34226 , Count:  665
# Three Ports: 33968  ,  34224  ,  33970 , Count:  665
# Three Ports: 33968  ,  34224  ,  33972 , Count:  649
# Three Ports: 33968  ,  34224  ,  34222 , Count:  507
# Three Ports: 33968  ,  34228  ,  33962 , Count:  645
# Three Ports: 33968  ,  34228  ,  33960 , Count:  639
# Three Ports: 33968  ,  34228  ,  33964 , Count:  608
# Three Ports: 33968  ,  34228  ,  34216 , Count:  636
# Three Ports: 33968  ,  34228  ,  34226 , Count:  636
# Three Ports: 33968  ,  34228  ,  33970 , Count:  619
# Three Ports: 33968  ,  34228  ,  33972 , Count:  604
# Three Ports: 33968  ,  33962  ,  33960 , Count:  652
# Three Ports: 33968  ,  33962  ,  33964 , Count:  624
# Three Ports: 33968  ,  33962  ,  34216 , Count:  646
# Three Ports: 33968  ,  33962  ,  34226 , Count:  664
# Three Ports: 33968  ,  33962  ,  33970 , Count:  643
# Three Ports: 33968  ,  33962  ,  33972 , Count:  631
# Three Ports: 33968  ,  33960  ,  33964 , Count:  648
# Three Ports: 33968  ,  33960  ,  34216 , Count:  651
# Three Ports: 33968  ,  33960  ,  34226 , Count:  667
# Three Ports: 33968  ,  33960  ,  33970 , Count:  632
# Three Ports: 33968  ,  33960  ,  33972 , Count:  639
# Three Ports: 33968  ,  33960  ,  34222 , Count:  507
# Three Ports: 33968  ,  33964  ,  34216 , Count:  625
# Three Ports: 33968  ,  33964  ,  34226 , Count:  650
# Three Ports: 33968  ,  33964  ,  33970 , Count:  623
# Three Ports: 33968  ,  33964  ,  33972 , Count:  599
# Three Ports: 33968  ,  34216  ,  34226 , Count:  645
# Three Ports: 33968  ,  34216  ,  33970 , Count:  628
# Three Ports: 33968  ,  34216  ,  33972 , Count:  643
# Three Ports: 33968  ,  34226  ,  33970 , Count:  645
# Three Ports: 33968  ,  34226  ,  33972 , Count:  641
# Three Ports: 33968  ,  33970  ,  33972 , Count:  621
# Three Ports: 34224  ,  34228  ,  33962 , Count:  645
# Three Ports: 34224  ,  34228  ,  33960 , Count:  623
# Three Ports: 34224  ,  34228  ,  33964 , Count:  612
# Three Ports: 34224  ,  34228  ,  34216 , Count:  634
# Three Ports: 34224  ,  34228  ,  34226 , Count:  641
# Three Ports: 34224  ,  34228  ,  33970 , Count:  615
# Three Ports: 34224  ,  34228  ,  33972 , Count:  622
# Three Ports: 34224  ,  33962  ,  33960 , Count:  655
# Three Ports: 34224  ,  33962  ,  33964 , Count:  634
# Three Ports: 34224  ,  33962  ,  34216 , Count:  634
# Three Ports: 34224  ,  33962  ,  34226 , Count:  644
# Three Ports: 34224  ,  33962  ,  33970 , Count:  650
# Three Ports: 34224  ,  33962  ,  33972 , Count:  638
# Three Ports: 34224  ,  33962  ,  34222 , Count:  501
# Three Ports: 34224  ,  33960  ,  33964 , Count:  636
# Three Ports: 34224  ,  33960  ,  34216 , Count:  638
# Three Ports: 34224  ,  33960  ,  34226 , Count:  664
# Three Ports: 34224  ,  33960  ,  33970 , Count:  644
# Three Ports: 34224  ,  33960  ,  33972 , Count:  639
# Three Ports: 34224  ,  33964  ,  34216 , Count:  623
# Three Ports: 34224  ,  33964  ,  34226 , Count:  636
# Three Ports: 34224  ,  33964  ,  33970 , Count:  637
# Three Ports: 34224  ,  33964  ,  33972 , Count:  619
# Three Ports: 34224  ,  34216  ,  34226 , Count:  650
# Three Ports: 34224  ,  34216  ,  33970 , Count:  651
# Three Ports: 34224  ,  34216  ,  33972 , Count:  658
# Three Ports: 34224  ,  34226  ,  33970 , Count:  629
# Three Ports: 34224  ,  34226  ,  33972 , Count:  634
# Three Ports: 34224  ,  33970  ,  33972 , Count:  647
# Three Ports: 34228  ,  33962  ,  33960 , Count:  638
# Three Ports: 34228  ,  33962  ,  33964 , Count:  631
# Three Ports: 34228  ,  33962  ,  34216 , Count:  641
# Three Ports: 34228  ,  33962  ,  34226 , Count:  639
# Three Ports: 34228  ,  33962  ,  33970 , Count:  639
# Three Ports: 34228  ,  33962  ,  33972 , Count:  617
# Three Ports: 34228  ,  33960  ,  33964 , Count:  620
# Three Ports: 34228  ,  33960  ,  34216 , Count:  617
# Three Ports: 34228  ,  33960  ,  34226 , Count:  635
# Three Ports: 34228  ,  33960  ,  33970 , Count:  602
# Three Ports: 34228  ,  33960  ,  33972 , Count:  598
# Three Ports: 34228  ,  33964  ,  34216 , Count:  610
# Three Ports: 34228  ,  33964  ,  34226 , Count:  624
# Three Ports: 34228  ,  33964  ,  33970 , Count:  605
# Three Ports: 34228  ,  33964  ,  33972 , Count:  584
# Three Ports: 34228  ,  34216  ,  34226 , Count:  624
# Three Ports: 34228  ,  34216  ,  33970 , Count:  618
# Three Ports: 34228  ,  34216  ,  33972 , Count:  606
# Three Ports: 34228  ,  34226  ,  33970 , Count:  623
# Three Ports: 34228  ,  34226  ,  33972 , Count:  614
# Three Ports: 34228  ,  33970  ,  33972 , Count:  580
# Three Ports: 33962  ,  33960  ,  33964 , Count:  643
# Three Ports: 33962  ,  33960  ,  34216 , Count:  637
# Three Ports: 33962  ,  33960  ,  34226 , Count:  656
# Three Ports: 33962  ,  33960  ,  33970 , Count:  636
# Three Ports: 33962  ,  33960  ,  33972 , Count:  615
# Three Ports: 33962  ,  33960  ,  33966 , Count:  506
# Three Ports: 33962  ,  33964  ,  34216 , Count:  620
# Three Ports: 33962  ,  33964  ,  34226 , Count:  636
# Three Ports: 33962  ,  33964  ,  33970 , Count:  635
# Three Ports: 33962  ,  33964  ,  33972 , Count:  621
# Three Ports: 33962  ,  34216  ,  34226 , Count:  646
# Three Ports: 33962  ,  34216  ,  33970 , Count:  650
# Three Ports: 33962  ,  34216  ,  33972 , Count:  637
# Three Ports: 33962  ,  34226  ,  33970 , Count:  635
# Three Ports: 33962  ,  34226  ,  33972 , Count:  639
# Three Ports: 33962  ,  33970  ,  33972 , Count:  633
# Three Ports: 33962  ,  33970  ,  34222 , Count:  501
# Three Ports: 33960  ,  33964  ,  34216 , Count:  614
# Three Ports: 33960  ,  33964  ,  34226 , Count:  656
# Three Ports: 33960  ,  33964  ,  33970 , Count:  619
# Three Ports: 33960  ,  33964  ,  33972 , Count:  616
# Three Ports: 33960  ,  34216  ,  34226 , Count:  663
# Three Ports: 33960  ,  34216  ,  33970 , Count:  625
# Three Ports: 33960  ,  34216  ,  33972 , Count:  631
# Three Ports: 33960  ,  34226  ,  33970 , Count:  642
# Three Ports: 33960  ,  34226  ,  33972 , Count:  645
# Three Ports: 33960  ,  34226  ,  34222 , Count:  502
# Three Ports: 33960  ,  33970  ,  33972 , Count:  624
# Three Ports: 33964  ,  34216  ,  34226 , Count:  619
# Three Ports: 33964  ,  34216  ,  33970 , Count:  616
# Three Ports: 33964  ,  34216  ,  33972 , Count:  606
# Three Ports: 33964  ,  34226  ,  33970 , Count:  631
# Three Ports: 33964  ,  34226  ,  33972 , Count:  629
# Three Ports: 33964  ,  33970  ,  33972 , Count:  616
# Three Ports: 34216  ,  34226  ,  33970 , Count:  641
# Three Ports: 34216  ,  34226  ,  33972 , Count:  642
# Three Ports: 34216  ,  33970  ,  33972 , Count:  630
# Three Ports: 34226  ,  33970  ,  33972 , Count:  628

# %%
DF3port = ss.createDataFrame(Three_Port_Sets_df)

# %%
# These output file names need to be changed in the cluster mode, so that you can compare them with those from the local mode.
output_path_3_port = "3PS_dfw5416_local.csv"
DF3port.write.option("header", True).csv(output_path_3_port)

# %%
ss.stop()

# %% [markdown]
# # Part E (cluster mode): Finding frequent 2-port sets and 3-port sets from the large dataset.

# %% [markdown]
# # Problem 8 (30 points)
# - Remove .master("local") from SparkSession statement
# - Change the input file to "Day_2020_profile.csv"
# - Change the threshold from 400 to 10000.
# - Change the output files to two different directories from the ones you used in local mode.
# - Export the notebook as a .py file
# - Run spark-submit on ICDS Roar
# - Submit the following items:
# -- (a) the .py file for cluster mode (10%)
# -- (b) One output csv file for frequent 2-port sets and one output CSV file for frequent 3-port sets generated in the cluster mode. (10%)
# -- (c) A screen shot (generated using `ls -l` terminal command) of your `MiniProj1` that shows all files and directories. (5%)
# -- (d) Discuss (in the cell below) three things you noticed that are interesting/surprising from the frequent 3-port sets (5%)

# %% [markdown]
# # Your Answer to Exercise 7 (d):
# 1. I found it surprising that the counts seem to fit a pattern so well. Most counts are very similar to one another if differentiated by a similar last value
# 2. Counts in the 100,000+ range are way higher than the next highest grouping
# 3. 23-80-8080 was by far the most frequent combination of anything starting with 23.
